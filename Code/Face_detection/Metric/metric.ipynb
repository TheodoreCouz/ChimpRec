# %% [markdown]
# <h2>Imports</h2>

# %%
import os
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
import seaborn as sns

#test_set = "/home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set"
#model_path = "/home/theo/Documents/Unif/Master/ChimpRec/Code/Face_detection/runs/detect/train3/weights/best.pt"
test_set = "C:/Users/julie/OneDrive - UCL/Master_2/Mémoire/Chimprec Dataset/face_detection_test_dataset"
model_path = "C:/Users/julie/OneDrive - UCL/Master_2/Mémoire/Chimprec Dataset/Models/face/v10s/weights/best.pt"

def yolo_to_relative_coord(bbox, img_dim):
    """
    Compute the coordinates of the bbox in pixels term.

    Args:
        bbox(tuple): Bbox in YOLO format.
        img_dim (tuple): Dimension of the image.

    Returns:
        tuple: The coordinate of the top left an the bottom right corner of the bbox in pixel term.
    """ 
    x_center, y_center, width, height = bbox
    img_w, img_h = img_dim
    
    x_min = (x_center - width / 2) * img_w
    y_min = (y_center - height / 2) * img_h
    x_max = (x_center + width / 2) * img_w
    y_max = (y_center + height / 2) * img_h
    
    return [x_min, y_min, x_max, y_max]

def convert_to_yolo(bbox, img_dim=(1080, 1920)):
    """
    Compute the coordinates of the bbox in pixels term.

    Args:
        bbox(tuple): Cordinate of the top left an the bottom right corner of the bbox in pixel term..
        img_dim (tuple): Dimension of the image.

    Returns:
        tuple: The coordinate of the bbox in YOLO format ([x_center, y_center, width, height]).
    """
    x1, y1, x2, y2 = bbox
    img_width, img_height = img_dim

    # Compute center coordinates
    x_center = (x1 + x2) / 2.0
    y_center = (y1 + y2) / 2.0

    # Compute width and height
    width = x2 - x1
    height = y2 - y1

    # Normalize values by image dimensions
    x_center /= img_width
    y_center /= img_height
    width /= img_width
    height /= img_height

    return [x_center, y_center, width, height]

def get_intersection(bbox1, bbox2, img_dim):
    """
    Compute the intersection of two bboxes.

    Args:
        bbox1, bbox2 (tuple): Two bboxes in YOLO format.
        img_dim (tuple): Dimension of the image.

    Returns:
        int: Value of the intersection of the two bboxes.
    """ 
    # conversion into relative coordinates
    Ax, Ay, Bx, By = yolo_to_relative_coord(bbox1, img_dim)
    Cx, Cy, Dx, Dy = yolo_to_relative_coord(bbox2, img_dim)

    # computation of the intersection
    x_overlap = min(Dx, Bx) - max(Ax, Cx)
    y_overlap = min(Dy, By) - max(Ay, Cy)
    if (x_overlap < 0 or y_overlap < 0): return 0 # no overlap case
    return x_overlap*y_overlap

def get_union(bbox1, bbox2, img_dim, intersection): 
    """
    Compute the union of two bboxes.

    Args:
        bbox1, bbox2 (tuple): Two bboxes in YOLO format.
        img_dim (tuple): Dimension of the image.
        intersection (int): Value of the intesection of the two bboxes.

    Returns:
        int: Value of the union of the two bboxes.
    """
    # conversion into relative coordinates
    Ax, Ay, Bx, By = yolo_to_relative_coord(bbox1, img_dim)
    Cx, Cy, Dx, Dy = yolo_to_relative_coord(bbox2, img_dim)

    # computation of the union
    area_1 = abs((Bx-Ax)*(By-Ay))
    area_2 = abs((Dx-Cx)*(Dy-Cy))
    return area_1 + area_2 - intersection


def iou(bbox1, bbox2, img_dim=(1080, 1920)):
    """
    Compute the iou of two bboxes.

    Args:
        bbox1, bbox2 (tuple): Two bboxes in YOLO format.
        img_dim (tuple): Dimension of the image.

    Returns:
        int: The intersection over union metric between bbox1 and bbox2.
    """
    intersection = get_intersection(bbox1, bbox2, img_dim)
    union = get_union(bbox1, bbox2, img_dim, intersection)
    # IoU
    return intersection/union

"""
The arguments <ground_truths> and <predictions> are expected to be 
python dictionaries structured as follows:

    dictionnary {
        image_name 1: [
                bbox 1,
                bbox 2, 
                ...
            ],
        image_name 2: [
                bbox 1,
                bbox 2, 
                ...
            ],
        ...
    }

PS: the bounding boxes are expected to be encoded in YOLO format.

    
For each image, every prediction bbox will be 
compared to every ground truth bbox to find the best match.

If a ground truth bbox finds no match among the prediction bbox:
+1 false negative

If a prediction bbox finds no match among the ground truth bbox:
+1 false positive

If the best match between a prediction bbox and the ground truth
bboxes has a low IoU (bellow a given threshold <t>):
+1 false positive

If a prediction bbox best match in the ground truth bboxes has
already been matched by another prediction bbox with a greater score:
+1 false positive

If the best match between a prediction bbox and the ground truth
bboxes has a high IoU (above a given threshold <t>):
+1 true positive

The true negative won't be counted because it means that no
prediction bbox has been found in the background. This is nonsense to count this.
"""
def extract_metrics(ground_truths:dict, predictions:dict, t=0.75):
    tp, fp, fn = 0, 0, 0  # Initialize counters for TP, FP, and FN
    
    # Iterate over all unique image names in ground truths and predictions
    for image_name in set(ground_truths.keys()).union(predictions.keys()):
        gt_bboxes = ground_truths.get(image_name, [])  # Retrieve ground truth bboxes (default empty list if missing)
        pred_bboxes = predictions.get(image_name, [])  # Retrieve predicted bboxes (default empty list if missing)
        
        matched_gt = set()  # Store indices of matched ground truth bboxes
        pred_matched_scores = []  # Keep track of IoU scores of matched predictions
        
        # Iterate over each predicted bounding box
        for pred in pred_bboxes:
            best_iou = 0  # Initialize the best IoU score for the current prediction
            best_gt_idx = -1  # Index of the best-matching ground truth bbox
            
            # Compare prediction with each ground truth bbox
            for i, gt in enumerate(gt_bboxes):
                score = iou(pred, gt)  # Compute IoU
                if score > best_iou:  # Update best match if IoU is higher
                    best_iou = score
                    best_gt_idx = i
            
            # Determine if the prediction is a TP or FP based on IoU and previous matches
            if best_iou >= t and best_gt_idx not in matched_gt:
                matched_gt.add(best_gt_idx)  # Mark ground truth bbox as matched
                pred_matched_scores.append(best_iou)  # Store IoU score
                tp += 1
            else:
                fp += 1
        
        # Count False Negatives (ground truths that were not matched)
        fn += len(gt_bboxes) - len(matched_gt)
    
    return {"true_positives": tp, "false_positives": fp, "false_negatives": fn}

def extract_ground_truth(test_set_path = test_set):
    path = f'{test_set_path}/labels'
    data = dict()

    # check whether the specified path is valid directory
    if not os.path.isdir(path):
        print(f"Error: {path} is not a valid directory.")
        return
    
    for textfile in os.listdir(path):
        file_path = f"{path}/{textfile}"

        # check whether textfile exists in the folder located at the specified path
        if os.path.isfile(file_path):
            data[textfile.strip(".txt")] = []

            # open the file in read mode
            with open(file_path, 'r') as file:

                # extract the bounding boxes one by one
                for line in file.readlines():
                    splitted = line.split(" ")
                    detection_class = splitted[0]
                    bbox = splitted[1:]
                    for i in range(len(bbox)): bbox[i] = float(bbox[i].strip("/n"))
                    data[textfile.strip(".txt")].append(bbox)
                file.close()
    
    return data

def predict(model_path, test_set_path, t_confidence = 0.4):
    """
    Predict bounding boxes using a YOLO model.

    Args:
        model_path (str): Path to the YOLO model.
        test_set_path (str): Path to the test set directory.

    Returns:
        dict: Dictionary with image prefixes as keys and predicted bounding boxes (YOLO format).
    """
    predictions = dict()

    # Load the YOLO model
    model = YOLO(model_path)

    test_set_path = f"{test_set_path}/images"

    # Ensure the test set path exists
    if not os.path.isdir(test_set_path):
        print(f"Error: Test set directory '{test_set_path}' not found.")
        return {}

    # Iterate over all images in the test set directory
    image_extension = ".png"
    for filename in sorted(os.listdir(test_set_path)):
        file_path = os.path.join(test_set_path, filename)

        # Check if the file is an image
        if not filename.lower().endswith(image_extension):
            continue

        filename_prefix = filename.split(".")[0]
        predictions[filename_prefix] = []

        # Run inference
        results = model(file_path)[0]

        # Extract YOLO format bounding boxes
        img = cv2.imread(file_path)
        img_height, img_width, _ = img.shape

        for result in results.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = result

            if score < t_confidence: continue

            # Convert bbox to YOLO format (normalized)
            x_center = ((x1 + x2) / 2) / img_width
            y_center = ((y1 + y2) / 2) / img_height
            width = (x2 - x1) / img_width
            height = (y2 - y1) / img_height

            predictions[filename_prefix].append((x_center, y_center, width, height))

    return predictions

def merge_boxes(predictions, merging_threshold, img_dim=(1080, 1920)):
    """
    Merge the bboxes that overlap too much.

    Args:
        predictions (dict): Dict of the predicted bboxes for each image of the dataset.
        merging_threshold (float): Minimum proportion of overlap needed to merge two bboxes.
        img_dim (tuple): Dimension of the image.

    Returns:
        dict: Dictionary with image prefixes as keys and predicted bounding boxes (YOLO format) merged when needed.
    """
    new_dict_predictions = {}
    for file in predictions: 
        new_predictions = []
        prediction = predictions[file]

        for pred1 in prediction: 
            Ax, Ay, Bx, By = yolo_to_relative_coord(pred1, img_dim)
            area1 = (Bx - Ax) * (By - Ay)

            for pred2 in new_predictions: 
                inter = get_intersection(pred1, pred2, img_dim)
                
                Cx, Cy, Dx, Dy = yolo_to_relative_coord(pred2, img_dim)
                area2 = (Dx - Cx) * (Dy - Cy)
                if inter / area1 > merging_threshold or inter / area2 > merging_threshold:        
                    # Fusion des coordonnées
                    Ax, Ay = min(Ax, Cx), min(Ay, Cy)
                    Bx, By = max(Bx, Dx), max(By, Dy)
                    new_predictions.remove(pred2)
            new_predictions.append(tuple(convert_to_yolo((Ax, Ay, Bx, By), img_dim)))
        new_dict_predictions[file] = new_predictions
    return new_dict_predictions

def draw_predictions(predictions, ground_truth, test_set_path, output_folder):
    """
    Draws predicted and ground truth bounding boxes on images and displays them in Jupyter Notebook.

    Args:
        predictions (dict): Dictionary of predicted bounding boxes in YOLO format.
        ground_truth (dict): Dictionary of ground truth bounding boxes in YOLO format.
        test_set_path (str): Path to the test set directory.

    Returns:
        None
    """
    test_set_path = f"{test_set_path}/images"

    for img_prefix, pred_bboxes in predictions.items():
        img_name = f"{img_prefix}.png"
        img_path = os.path.join(test_set_path, img_name)
        output_path = os.path.join(output_folder, img_name)

        # Load image
        image = cv2.imread(img_path)
        if image is None:
            print(f"Error: Unable to load image {img_name}")
            continue

        # Convert from BGR to RGB for correct color display
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        img_height, img_width, _ = image.shape

        def draw_bbox(image, bbox, color, label=None):
            """ Draws a single bounding box on the image. """
            x_center, y_center, width, height = bbox

            # Convert YOLO format to absolute pixel coordinates
            x1 = int((x_center - width / 2) * img_width)
            y1 = int((y_center - height / 2) * img_height)
            x2 = int((x_center + width / 2) * img_width)
            y2 = int((y_center + height / 2) * img_height)

            # Draw rectangle
            cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)

            # Put label
            if label:
                font = cv2.FONT_HERSHEY_SIMPLEX
                font_scale = 0.5
                thickness = 1
                cv2.putText(image, label, (x1, max(y1 - 5, 10)), font, font_scale, color, thickness, cv2.LINE_AA)

        # Draw ground truth boxes (green)
        if img_prefix in ground_truth:
            for bbox in ground_truth[img_prefix]:
                draw_bbox(image, bbox, (0, 255, 0))  # Class label only

        # Draw predicted boxes (blue)
        for bbox in pred_bboxes:
            draw_bbox(image, bbox, (255, 0, 0), f"P {int(bbox[0])}")  # Class & confidence

        image_bgr = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        cv2.imwrite(output_path, image_bgr)

# %% [markdown]
# <h1>Effective code</h1>

# %% [markdown]
# <h3>Ground truth extraction.</h3>

# %%
t = 0.6
t_confidence = 0.35
merging_threshold = 0.8

GT = extract_ground_truth()
predictions = predict(model_path, test_set, t_confidence=t_confidence)
# Out:
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body0.png: 416x640 1 Face, 111.1ms
# Speed: 8.0ms preprocess, 111.1ms inference, 57.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body1.png: 576x640 1 Face, 152.9ms
# Speed: 4.8ms preprocess, 152.9ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body10.png: 640x640 2 Faces, 54.8ms
# Speed: 8.6ms preprocess, 54.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body100.png: 640x384 1 Face, 174.1ms
# Speed: 4.6ms preprocess, 174.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body101.png: 640x448 1 Face, 132.6ms
# Speed: 5.4ms preprocess, 132.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body102.png: 544x640 1 Face, 139.9ms
# Speed: 6.2ms preprocess, 139.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body103.png: 640x384 1 Face, 35.0ms
# Speed: 3.8ms preprocess, 35.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body104.png: 544x640 2 Faces, 33.7ms
# Speed: 12.2ms preprocess, 33.7ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body105.png: 640x480 1 Face, 134.2ms
# Speed: 3.8ms preprocess, 134.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body106.png: 640x352 1 Face, 138.4ms
# Speed: 2.8ms preprocess, 138.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body107.png: 640x288 1 Face, 140.7ms
# Speed: 1.5ms preprocess, 140.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body108.png: 608x640 (no detections), 119.1ms
# Speed: 7.2ms preprocess, 119.1ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body109.png: 640x544 1 Face, 132.6ms
# Speed: 6.4ms preprocess, 132.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body11.png: 640x544 1 Face, 24.0ms
# Speed: 4.8ms preprocess, 24.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body110.png: 640x640 2 Faces, 27.5ms
# Speed: 7.8ms preprocess, 27.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body111.png: 608x640 1 Face, 26.7ms
# Speed: 6.2ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body112.png: 640x512 2 Faces, 133.0ms
# Speed: 3.3ms preprocess, 133.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body113.png: 640x256 1 Face, 125.9ms
# Speed: 2.6ms preprocess, 125.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 256)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body114.png: 608x640 1 Face, 24.1ms
# Speed: 4.8ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body115.png: 640x480 1 Face, 31.4ms
# Speed: 5.8ms preprocess, 31.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body116.png: 640x288 1 Face, 27.6ms
# Speed: 3.0ms preprocess, 27.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body117.png: 640x384 1 Face, 23.5ms
# Speed: 3.3ms preprocess, 23.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body118.png: 640x480 1 Face, 27.1ms
# Speed: 3.5ms preprocess, 27.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body119.png: 576x640 1 Face, 27.4ms
# Speed: 5.8ms preprocess, 27.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body12.png: 640x640 1 Face, 26.6ms
# Speed: 5.9ms preprocess, 26.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body120.png: 640x512 1 Face, 26.8ms
# Speed: 2.8ms preprocess, 26.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body121.png: 640x544 1 Face, 28.1ms
# Speed: 4.3ms preprocess, 28.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body122.png: 640x480 1 Face, 26.4ms
# Speed: 4.3ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body123.png: 640x448 2 Faces, 26.7ms
# Speed: 2.8ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body124.png: 640x480 1 Face, 32.9ms
# Speed: 3.7ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body125.png: 416x640 2 Faces, 23.5ms
# Speed: 2.8ms preprocess, 23.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body126.png: 640x544 2 Faces, 29.0ms
# Speed: 4.7ms preprocess, 29.0ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body127.png: 640x480 2 Faces, 31.9ms
# Speed: 3.9ms preprocess, 31.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body128.png: 640x640 1 Face, 23.4ms
# Speed: 7.1ms preprocess, 23.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body129.png: 640x608 1 Face, 120.1ms
# Speed: 7.6ms preprocess, 120.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body13.png: 640x480 1 Face, 30.0ms
# Speed: 3.3ms preprocess, 30.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body130.png: 640x576 1 Face, 113.0ms
# Speed: 4.8ms preprocess, 113.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body131.png: 640x576 1 Face, 25.7ms
# Speed: 7.3ms preprocess, 25.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body132.png: 640x576 1 Face, 38.9ms
# Speed: 7.5ms preprocess, 38.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body133.png: 640x352 1 Face, 30.4ms
# Speed: 2.0ms preprocess, 30.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body134.png: 640x640 2 Faces, 29.6ms
# Speed: 7.4ms preprocess, 29.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body135.png: 416x640 1 Face, 27.6ms
# Speed: 3.5ms preprocess, 27.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body136.png: 512x640 1 Face, 123.9ms
# Speed: 3.5ms preprocess, 123.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body137.png: 640x256 1 Face, 28.2ms
# Speed: 1.8ms preprocess, 28.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 256)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body138.png: 640x448 1 Face, 30.1ms
# Speed: 4.2ms preprocess, 30.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body139.png: 640x448 1 Face, 29.1ms
# Speed: 4.6ms preprocess, 29.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body14.png: 640x512 1 Face, 27.9ms
# Speed: 4.1ms preprocess, 27.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body140.png: 640x288 1 Face, 28.3ms
# Speed: 2.2ms preprocess, 28.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body141.png: 640x640 1 Face, 29.4ms
# Speed: 5.9ms preprocess, 29.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body142.png: 640x288 2 Faces, 27.5ms
# Speed: 1.8ms preprocess, 27.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body143.png: 640x416 2 Faces, 101.8ms
# Speed: 3.2ms preprocess, 101.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body144.png: 640x512 2 Faces, 25.8ms
# Speed: 4.2ms preprocess, 25.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body145.png: 640x544 2 Faces, 29.9ms
# Speed: 5.7ms preprocess, 29.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body146.png: 448x640 1 Face, 121.6ms
# Speed: 3.3ms preprocess, 121.6ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body147.png: 480x640 1 Face, 117.2ms
# Speed: 2.9ms preprocess, 117.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body148.png: 416x640 1 Face, 28.5ms
# Speed: 3.4ms preprocess, 28.5ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body149.png: 480x640 1 Face, 34.7ms
# Speed: 4.5ms preprocess, 34.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body15.png: 640x512 1 Face, 33.3ms
# Speed: 4.0ms preprocess, 33.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body150.png: 640x384 1 Face, 30.2ms
# Speed: 4.1ms preprocess, 30.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body151.png: 640x576 1 Face, 27.3ms
# Speed: 7.6ms preprocess, 27.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body152.png: 640x544 2 Faces, 26.8ms
# Speed: 6.7ms preprocess, 26.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body153.png: 640x416 1 Face, 29.2ms
# Speed: 4.7ms preprocess, 29.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body154.png: 640x608 2 Faces, 30.1ms
# Speed: 8.2ms preprocess, 30.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body155.png: 640x576 1 Face, 28.0ms
# Speed: 6.1ms preprocess, 28.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body156.png: 640x544 1 Face, 26.7ms
# Speed: 7.8ms preprocess, 26.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body157.png: 608x640 2 Faces, 30.3ms
# Speed: 8.0ms preprocess, 30.3ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body158.png: 608x640 2 Faces, 27.7ms
# Speed: 7.7ms preprocess, 27.7ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body159.png: 640x576 2 Faces, 28.5ms
# Speed: 10.0ms preprocess, 28.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body16.png: 448x640 1 Face, 27.0ms
# Speed: 3.7ms preprocess, 27.0ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body160.png: 576x640 1 Face, 28.7ms
# Speed: 5.9ms preprocess, 28.7ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body161.png: 640x416 (no detections), 34.9ms
# Speed: 5.4ms preprocess, 34.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body162.png: 640x608 2 Faces, 30.4ms
# Speed: 9.2ms preprocess, 30.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body163.png: 640x640 2 Faces, 36.0ms
# Speed: 6.2ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body164.png: 640x640 1 Face, 28.7ms
# Speed: 8.4ms preprocess, 28.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body165.png: 640x608 1 Face, 33.2ms
# Speed: 7.7ms preprocess, 33.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body166.png: 640x576 1 Face, 35.8ms
# Speed: 10.2ms preprocess, 35.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body167.png: 640x640 1 Face, 29.6ms
# Speed: 8.2ms preprocess, 29.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body168.png: 640x512 1 Face, 41.7ms
# Speed: 4.8ms preprocess, 41.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body169.png: 576x640 1 Face, 35.3ms
# Speed: 7.5ms preprocess, 35.3ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body17.png: 640x480 1 Face, 27.7ms
# Speed: 3.2ms preprocess, 27.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body170.png: 544x640 2 Faces, 27.0ms
# Speed: 6.1ms preprocess, 27.0ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body171.png: 640x576 1 Face, 33.0ms
# Speed: 8.5ms preprocess, 33.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body172.png: 640x320 1 Face, 117.6ms
# Speed: 3.6ms preprocess, 117.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body173.png: 640x448 1 Face, 26.1ms
# Speed: 4.1ms preprocess, 26.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body174.png: 608x640 1 Face, 29.5ms
# Speed: 6.7ms preprocess, 29.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body175.png: 640x544 2 Faces, 32.6ms
# Speed: 5.1ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body176.png: 640x416 1 Face, 32.8ms
# Speed: 3.4ms preprocess, 32.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body177.png: 576x640 1 Face, 27.0ms
# Speed: 6.9ms preprocess, 27.0ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body178.png: 640x608 1 Face, 28.6ms
# Speed: 8.1ms preprocess, 28.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body179.png: 640x544 1 Face, 37.1ms
# Speed: 5.3ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body18.png: 640x512 1 Face, 29.4ms
# Speed: 3.8ms preprocess, 29.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body180.png: 576x640 1 Face, 29.9ms
# Speed: 6.0ms preprocess, 29.9ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body181.png: 640x544 1 Face, 25.2ms
# Speed: 4.7ms preprocess, 25.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body182.png: 640x544 1 Face, 24.0ms
# Speed: 6.9ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body183.png: 512x640 1 Face, 29.9ms
# Speed: 3.5ms preprocess, 29.9ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body184.png: 640x416 1 Face, 30.5ms
# Speed: 4.2ms preprocess, 30.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body185.png: 544x640 1 Face, 25.8ms
# Speed: 7.9ms preprocess, 25.8ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body186.png: 640x352 1 Face, 32.4ms
# Speed: 3.5ms preprocess, 32.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body187.png: 640x384 1 Face, 27.4ms
# Speed: 3.2ms preprocess, 27.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body188.png: 576x640 1 Face, 32.3ms
# Speed: 5.7ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body189.png: 640x352 1 Face, 24.8ms
# Speed: 3.4ms preprocess, 24.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body19.png: 640x640 2 Faces, 29.5ms
# Speed: 9.2ms preprocess, 29.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body190.png: 640x640 2 Faces, 27.6ms
# Speed: 10.3ms preprocess, 27.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body191.png: 640x544 1 Face, 27.9ms
# Speed: 6.8ms preprocess, 27.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body192.png: 640x352 (no detections), 31.1ms
# Speed: 3.2ms preprocess, 31.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body193.png: 640x352 1 Face, 26.2ms
# Speed: 3.4ms preprocess, 26.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body194.png: 640x544 1 Face, 30.9ms
# Speed: 4.8ms preprocess, 30.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body195.png: 640x512 2 Faces, 27.6ms
# Speed: 4.6ms preprocess, 27.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body196.png: 640x512 1 Face, 24.6ms
# Speed: 5.8ms preprocess, 24.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body197.png: 480x640 1 Face, 26.8ms
# Speed: 3.1ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body198.png: 640x416 1 Face, 29.7ms
# Speed: 3.7ms preprocess, 29.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body199.png: 640x288 1 Face, 25.6ms
# Speed: 3.2ms preprocess, 25.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body2.png: 640x480 1 Face, 26.6ms
# Speed: 3.4ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body20.png: 640x640 1 Face, 29.0ms
# Speed: 9.0ms preprocess, 29.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body200.png: 640x576 1 Face, 30.6ms
# Speed: 7.1ms preprocess, 30.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body201.png: 640x320 1 Face, 30.3ms
# Speed: 3.1ms preprocess, 30.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body202.png: 640x480 2 Faces, 25.6ms
# Speed: 4.8ms preprocess, 25.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body203.png: 640x480 1 Face, 26.9ms
# Speed: 5.3ms preprocess, 26.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body204.png: 640x640 1 Face, 29.5ms
# Speed: 7.3ms preprocess, 29.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body205.png: 640x640 1 Face, 26.6ms
# Speed: 5.9ms preprocess, 26.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body206.png: 640x576 (no detections), 28.1ms
# Speed: 5.5ms preprocess, 28.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body207.png: 640x448 1 Face, 28.9ms
# Speed: 3.1ms preprocess, 28.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body208.png: 480x640 (no detections), 27.7ms
# Speed: 3.7ms preprocess, 27.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body209.png: 576x640 2 Faces, 25.3ms
# Speed: 7.3ms preprocess, 25.3ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body21.png: 640x448 1 Face, 32.6ms
# Speed: 4.3ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body210.png: 640x512 1 Face, 38.3ms
# Speed: 4.5ms preprocess, 38.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body211.png: 544x640 1 Face, 29.2ms
# Speed: 5.9ms preprocess, 29.2ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body212.png: 640x544 (no detections), 38.8ms
# Speed: 4.7ms preprocess, 38.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body213.png: 640x640 2 Faces, 29.7ms
# Speed: 6.9ms preprocess, 29.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body214.png: 640x512 1 Face, 28.9ms
# Speed: 3.8ms preprocess, 28.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body215.png: 640x576 2 Faces, 26.6ms
# Speed: 4.5ms preprocess, 26.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body216.png: 544x640 1 Face, 30.2ms
# Speed: 5.5ms preprocess, 30.2ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body217.png: 544x640 2 Faces, 26.6ms
# Speed: 7.6ms preprocess, 26.6ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body218.png: 384x640 1 Face, 131.8ms
# Speed: 2.4ms preprocess, 131.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body219.png: 640x608 (no detections), 34.0ms
# Speed: 6.9ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body22.png: 640x448 1 Face, 27.5ms
# Speed: 5.4ms preprocess, 27.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body220.png: 544x640 1 Face, 28.7ms
# Speed: 4.8ms preprocess, 28.7ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body221.png: 640x384 1 Face, 38.0ms
# Speed: 3.7ms preprocess, 38.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body222.png: 640x416 1 Face, 31.0ms
# Speed: 2.6ms preprocess, 31.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body223.png: 640x384 (no detections), 28.4ms
# Speed: 2.8ms preprocess, 28.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body224.png: 512x640 1 Face, 25.9ms
# Speed: 3.6ms preprocess, 25.9ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body225.png: 640x416 1 Face, 33.0ms
# Speed: 3.6ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body226.png: 640x448 1 Face, 28.9ms
# Speed: 3.5ms preprocess, 28.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body227.png: 640x416 1 Face, 31.6ms
# Speed: 3.4ms preprocess, 31.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body228.png: 544x640 1 Face, 37.4ms
# Speed: 3.9ms preprocess, 37.4ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body229.png: 640x448 (no detections), 31.3ms
# Speed: 3.7ms preprocess, 31.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body23.png: 640x544 (no detections), 30.8ms
# Speed: 4.1ms preprocess, 30.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body230.png: 640x320 1 Face, 33.2ms
# Speed: 3.2ms preprocess, 33.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body231.png: 544x640 2 Faces, 29.4ms
# Speed: 5.1ms preprocess, 29.4ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body232.png: 544x640 1 Face, 29.0ms
# Speed: 6.9ms preprocess, 29.0ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body233.png: 512x640 2 Faces, 32.9ms
# Speed: 4.2ms preprocess, 32.9ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body234.png: 640x384 1 Face, 31.8ms
# Speed: 2.2ms preprocess, 31.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body235.png: 640x256 2 Faces, 32.9ms
# Speed: 4.7ms preprocess, 32.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 256)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body236.png: 576x640 1 Face, 37.9ms
# Speed: 6.6ms preprocess, 37.9ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body237.png: 416x640 1 Face, 34.9ms
# Speed: 3.7ms preprocess, 34.9ms inference, 3.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body238.png: 640x352 1 Face, 39.2ms
# Speed: 3.5ms preprocess, 39.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body239.png: 512x640 1 Face, 37.1ms
# Speed: 5.9ms preprocess, 37.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body24.png: 640x576 (no detections), 33.7ms
# Speed: 6.8ms preprocess, 33.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body240.png: 416x640 1 Face, 35.5ms
# Speed: 3.4ms preprocess, 35.5ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body241.png: 448x640 1 Face, 32.2ms
# Speed: 3.5ms preprocess, 32.2ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body242.png: 640x608 1 Face, 34.0ms
# Speed: 7.3ms preprocess, 34.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body243.png: 640x224 (no detections), 126.0ms
# Speed: 2.7ms preprocess, 126.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 224)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body244.png: 640x384 1 Face, 32.8ms
# Speed: 3.4ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body245.png: 480x640 2 Faces, 34.7ms
# Speed: 6.6ms preprocess, 34.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body246.png: 416x640 1 Face, 25.4ms
# Speed: 3.6ms preprocess, 25.4ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body247.png: 640x640 1 Face, 50.6ms
# Speed: 6.3ms preprocess, 50.6ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body248.png: 640x384 1 Face, 35.4ms
# Speed: 3.7ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body249.png: 640x224 1 Face, 30.9ms
# Speed: 2.1ms preprocess, 30.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 224)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body25.png: 640x480 (no detections), 30.8ms
# Speed: 3.4ms preprocess, 30.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body250.png: 640x288 1 Face, 32.1ms
# Speed: 3.4ms preprocess, 32.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body251.png: 640x576 1 Face, 31.5ms
# Speed: 10.2ms preprocess, 31.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body252.png: 640x288 1 Face, 27.9ms
# Speed: 3.2ms preprocess, 27.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body253.png: 640x512 1 Face, 32.0ms
# Speed: 5.2ms preprocess, 32.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body254.png: 640x448 1 Face, 24.5ms
# Speed: 4.7ms preprocess, 24.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body255.png: 480x640 2 Faces, 29.5ms
# Speed: 4.1ms preprocess, 29.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body256.png: 640x576 1 Face, 34.6ms
# Speed: 5.9ms preprocess, 34.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body257.png: 640x544 1 Face, 33.2ms
# Speed: 6.7ms preprocess, 33.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body258.png: 640x608 1 Face, 33.3ms
# Speed: 8.7ms preprocess, 33.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body259.png: 640x352 1 Face, 31.7ms
# Speed: 4.0ms preprocess, 31.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body26.png: 576x640 1 Face, 31.6ms
# Speed: 5.6ms preprocess, 31.6ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body260.png: 640x288 2 Faces, 33.7ms
# Speed: 3.2ms preprocess, 33.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body261.png: 640x320 1 Face, 25.1ms
# Speed: 3.4ms preprocess, 25.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body262.png: 640x288 (no detections), 26.2ms
# Speed: 2.5ms preprocess, 26.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body263.png: 448x640 1 Face, 27.6ms
# Speed: 3.6ms preprocess, 27.6ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body264.png: 544x640 1 Face, 33.4ms
# Speed: 4.4ms preprocess, 33.4ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body265.png: 640x640 1 Face, 32.5ms
# Speed: 4.3ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body266.png: 608x640 1 Face, 33.5ms
# Speed: 5.0ms preprocess, 33.5ms inference, 1.7ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body267.png: 640x352 1 Face, 53.4ms
# Speed: 1.9ms preprocess, 53.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body268.png: 640x480 1 Face, 52.9ms
# Speed: 2.9ms preprocess, 52.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body269.png: 320x640 (no detections), 105.5ms
# Speed: 2.3ms preprocess, 105.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body27.png: 640x384 (no detections), 20.6ms
# Speed: 3.6ms preprocess, 20.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body270.png: 640x320 1 Face, 23.8ms
# Speed: 2.8ms preprocess, 23.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body271.png: 576x640 (no detections), 30.2ms
# Speed: 3.7ms preprocess, 30.2ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body272.png: 640x320 1 Face, 22.8ms
# Speed: 2.6ms preprocess, 22.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body273.png: 640x480 2 Faces, 24.5ms
# Speed: 2.7ms preprocess, 24.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body274.png: 640x480 1 Face, 22.9ms
# Speed: 2.9ms preprocess, 22.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body275.png: 640x224 1 Face, 16.1ms
# Speed: 1.7ms preprocess, 16.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 224)
#
# ...
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body4.png: 448x640 1 Face, 20.0ms
# Speed: 2.7ms preprocess, 20.0ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body40.png: 640x448 1 Face, 20.3ms
# Speed: 3.5ms preprocess, 20.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body41.png: 640x608 1 Face, 29.3ms
# Speed: 5.9ms preprocess, 29.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body42.png: 640x448 1 Face, 19.5ms
# Speed: 2.6ms preprocess, 19.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body43.png: 640x384 1 Face, 18.5ms
# Speed: 2.3ms preprocess, 18.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body44.png: 640x416 1 Face, 18.6ms
# Speed: 3.2ms preprocess, 18.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body45.png: 320x640 1 Face, 15.0ms
# Speed: 1.8ms preprocess, 15.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body46.png: 640x448 (no detections), 19.7ms
# Speed: 3.3ms preprocess, 19.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body47.png: 576x640 1 Face, 26.7ms
# Speed: 4.1ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body48.png: 640x544 (no detections), 25.5ms
# Speed: 3.0ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body49.png: 640x640 1 Face, 27.8ms
# Speed: 5.1ms preprocess, 27.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body5.png: 640x640 (no detections), 29.8ms
# Speed: 7.9ms preprocess, 29.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body50.png: 384x640 1 Face, 20.8ms
# Speed: 3.7ms preprocess, 20.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body51.png: 640x576 2 Faces, 24.7ms
# Speed: 3.3ms preprocess, 24.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body52.png: 544x640 1 Face, 24.0ms
# Speed: 3.2ms preprocess, 24.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body53.png: 512x640 1 Face, 22.0ms
# Speed: 4.1ms preprocess, 22.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body54.png: 640x352 1 Face, 23.3ms
# Speed: 4.1ms preprocess, 23.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body55.png: 576x640 (no detections), 25.2ms
# Speed: 3.5ms preprocess, 25.2ms inference, 0.4ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body56.png: 640x480 1 Face, 15.6ms
# Speed: 1.8ms preprocess, 15.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body57.png: 640x640 1 Face, 18.3ms
# Speed: 3.2ms preprocess, 18.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body58.png: 608x640 1 Face, 17.8ms
# Speed: 4.8ms preprocess, 17.8ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body59.png: 544x640 1 Face, 14.0ms
# Speed: 2.3ms preprocess, 14.0ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body6.png: 480x640 (no detections), 20.3ms
# Speed: 2.0ms preprocess, 20.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body60.png: 640x384 2 Faces, 19.5ms
# Speed: 1.7ms preprocess, 19.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body61.png: 640x640 3 Faces, 14.1ms
# Speed: 4.8ms preprocess, 14.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body62.png: 544x640 2 Faces, 14.5ms
# Speed: 2.8ms preprocess, 14.5ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body63.png: 480x640 1 Face, 16.3ms
# Speed: 3.2ms preprocess, 16.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body64.png: 480x640 1 Face, 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body65.png: 640x448 1 Face, 16.9ms
# Speed: 4.0ms preprocess, 16.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body66.png: 640x576 (no detections), 18.2ms
# Speed: 2.7ms preprocess, 18.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body67.png: 640x512 1 Face, 17.6ms
# Speed: 2.6ms preprocess, 17.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body68.png: 640x640 1 Face, 13.7ms
# Speed: 3.3ms preprocess, 13.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body69.png: 640x512 1 Face, 17.5ms
# Speed: 2.2ms preprocess, 17.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body7.png: 512x640 1 Face, 20.2ms
# Speed: 2.3ms preprocess, 20.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body70.png: 288x640 1 Face, 66.8ms
# Speed: 1.5ms preprocess, 66.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body71.png: 448x640 1 Face, 14.6ms
# Speed: 1.6ms preprocess, 14.6ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body72.png: 640x480 1 Face, 44.6ms
# Speed: 1.7ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body73.png: 608x640 1 Face, 15.3ms
# Speed: 3.4ms preprocess, 15.3ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body74.png: 640x384 1 Face, 16.9ms
# Speed: 1.7ms preprocess, 16.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body75.png: 640x384 (no detections), 15.6ms
# Speed: 1.5ms preprocess, 15.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body76.png: 640x448 1 Face, 14.0ms
# Speed: 1.8ms preprocess, 14.0ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body77.png: 640x576 1 Face, 15.9ms
# Speed: 4.1ms preprocess, 15.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body78.png: 544x640 1 Face, 20.4ms
# Speed: 2.6ms preprocess, 20.4ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body79.png: 576x640 1 Face, 13.7ms
# Speed: 4.7ms preprocess, 13.7ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body8.png: 640x480 1 Face, 15.4ms
# Speed: 1.9ms preprocess, 15.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body80.png: 640x640 2 Faces, 15.1ms
# Speed: 3.6ms preprocess, 15.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body81.png: 640x416 (no detections), 21.2ms
# Speed: 2.1ms preprocess, 21.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body82.png: 640x480 1 Face, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body83.png: 640x384 1 Face, 39.6ms
# Speed: 2.4ms preprocess, 39.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body84.png: 640x416 (no detections), 14.8ms
# Speed: 2.4ms preprocess, 14.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body85.png: 640x480 2 Faces, 29.1ms
# Speed: 1.7ms preprocess, 29.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body86.png: 640x480 1 Face, 19.0ms
# Speed: 1.8ms preprocess, 19.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body87.png: 448x640 1 Face, 13.9ms
# Speed: 2.0ms preprocess, 13.9ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body88.png: 640x640 1 Face, 22.5ms
# Speed: 4.7ms preprocess, 22.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body89.png: 640x480 1 Face, 14.0ms
# Speed: 1.7ms preprocess, 14.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body9.png: 480x640 1 Face, 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body90.png: 640x512 1 Face, 25.4ms
# Speed: 2.8ms preprocess, 25.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body91.png: 640x640 3 Faces, 24.3ms
# Speed: 3.8ms preprocess, 24.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body92.png: 640x640 (no detections), 22.2ms
# Speed: 3.3ms preprocess, 22.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body93.png: 608x640 1 Face, 28.6ms
# Speed: 4.7ms preprocess, 28.6ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body94.png: 640x608 1 Face, 28.4ms
# Speed: 3.7ms preprocess, 28.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body95.png: 640x640 1 Face, 30.5ms
# Speed: 5.5ms preprocess, 30.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body96.png: 640x640 1 Face, 27.3ms
# Speed: 5.7ms preprocess, 27.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body97.png: 640x608 1 Face, 28.1ms
# Speed: 4.8ms preprocess, 28.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body98.png: 640x640 1 Face, 28.2ms
# Speed: 4.5ms preprocess, 28.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body99.png: 576x640 1 Face, 25.1ms
# Speed: 4.1ms preprocess, 25.1ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)

# %% [markdown]
# <h3>Computation of the model performance</h3>

# %%
results = extract_metrics(GT, predictions, t=t)

tp, fp, fn = results.values()

print(results)
print(f"precision={tp/(tp+fp)}")
print(f"recall={tp/(tp+fn)}")
# Out:
# {'true_positives': 230, 'false_positives': 90, 'false_negatives': 111}
# precision=0.71875
# recall=0.6744868035190615

# %% [markdown]
# <h2>Graphs</h2>

# %%
"""
Precision and recall as a function of the confidence threshold
"""
iterators = [i/20 for i in range(1, 20, 1)]

data = dict()
n_pred_list = []

for i in iterators:
    pred = predict(model_path, test_set, i)
    results = extract_metrics(GT, pred, t=t)
    tp, fp, fn = results.values()
    if (tp+fp) == 0: precision = 0
    else: precision=tp/(tp+fp)

    if (tp+fn) == 0: recall = 0
    else: recall=tp/(tp+fn)
    data[i] = (precision, recall)
    n_pred = 0
    for values in pred.values():
        n_pred += len(values)
    n_pred_list.append(n_pred)
# Out:
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body0.png: 416x640 1 Face, 20.8ms
# Speed: 4.0ms preprocess, 20.8ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body1.png: 576x640 3 Faces, 26.5ms
# Speed: 8.6ms preprocess, 26.5ms inference, 6.0ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body10.png: 640x640 (no detections), 24.4ms
# Speed: 10.2ms preprocess, 24.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body100.png: 640x384 1 Face, 26.9ms
# Speed: 3.7ms preprocess, 26.9ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body101.png: 640x448 (no detections), 17.6ms
# Speed: 4.3ms preprocess, 17.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body102.png: 544x640 2 Faces, 22.9ms
# Speed: 6.5ms preprocess, 22.9ms inference, 2.7ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body103.png: 640x384 1 Face, 21.8ms
# Speed: 3.9ms preprocess, 21.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body104.png: 544x640 2 Faces, 24.3ms
# Speed: 6.0ms preprocess, 24.3ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body105.png: 640x480 1 Face, 18.8ms
# Speed: 5.2ms preprocess, 18.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body106.png: 640x352 1 Face, 16.7ms
# Speed: 4.5ms preprocess, 16.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body107.png: 640x288 1 Face, 19.6ms
# Speed: 3.2ms preprocess, 19.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body108.png: 608x640 2 Faces, 23.5ms
# Speed: 7.8ms preprocess, 23.5ms inference, 2.8ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body109.png: 640x544 1 Face, 22.5ms
# Speed: 8.7ms preprocess, 22.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body11.png: 640x544 1 Face, 20.8ms
# Speed: 8.5ms preprocess, 20.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body110.png: 640x640 3 Faces, 24.0ms
# Speed: 5.5ms preprocess, 24.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body111.png: 608x640 1 Face, 23.1ms
# Speed: 4.8ms preprocess, 23.1ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body112.png: 640x512 1 Face, 18.6ms
# Speed: 3.5ms preprocess, 18.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body113.png: 640x256 1 Face, 12.4ms
# Speed: 1.7ms preprocess, 12.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 256)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body114.png: 608x640 1 Face, 23.2ms
# Speed: 5.5ms preprocess, 23.2ms inference, 1.8ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body115.png: 640x480 1 Face, 18.4ms
# Speed: 2.8ms preprocess, 18.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body116.png: 640x288 1 Face, 13.5ms
# Speed: 1.9ms preprocess, 13.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body117.png: 640x384 1 Face, 18.7ms
# Speed: 2.8ms preprocess, 18.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body118.png: 640x480 1 Face, 16.4ms
# Speed: 3.8ms preprocess, 16.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body119.png: 576x640 1 Face, 20.2ms
# Speed: 5.2ms preprocess, 20.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body12.png: 640x640 2 Faces, 21.4ms
# Speed: 5.0ms preprocess, 21.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body120.png: 640x512 1 Face, 17.9ms
# Speed: 3.2ms preprocess, 17.9ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body121.png: 640x544 1 Face, 17.6ms
# Speed: 5.1ms preprocess, 17.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body122.png: 640x480 1 Face, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body123.png: 640x448 2 Faces, 14.0ms
# Speed: 2.6ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body124.png: 640x480 1 Face, 14.7ms
# Speed: 3.1ms preprocess, 14.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body125.png: 416x640 1 Face, 13.9ms
# Speed: 2.7ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body126.png: 640x544 1 Face, 18.7ms
# Speed: 9.2ms preprocess, 18.7ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body127.png: 640x480 1 Face, 10.4ms
# Speed: 2.5ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body128.png: 640x640 1 Face, 12.6ms
# Speed: 4.4ms preprocess, 12.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body129.png: 640x608 1 Face, 14.8ms
# Speed: 4.4ms preprocess, 14.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body13.png: 640x480 1 Face, 9.8ms
# Speed: 2.3ms preprocess, 9.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body130.png: 640x576 1 Face, 12.5ms
# Speed: 5.6ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body131.png: 640x576 1 Face, 11.8ms
# Speed: 4.8ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body132.png: 640x576 1 Face, 15.4ms
# Speed: 4.2ms preprocess, 15.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body133.png: 640x352 1 Face, 8.4ms
# Speed: 1.7ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body134.png: 640x640 1 Face, 17.0ms
# Speed: 4.6ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body135.png: 416x640 1 Face, 9.5ms
# Speed: 2.3ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body136.png: 512x640 2 Faces, 10.7ms
# Speed: 4.5ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body137.png: 640x256 1 Face, 19.7ms
# Speed: 1.8ms preprocess, 19.7ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 256)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body138.png: 640x448 1 Face, 9.3ms
# Speed: 3.5ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body139.png: 640x448 1 Face, 9.6ms
# Speed: 2.4ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body14.png: 640x512 (no detections), 10.4ms
# Speed: 2.3ms preprocess, 10.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body140.png: 640x288 1 Face, 11.4ms
# Speed: 1.6ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body141.png: 640x640 2 Faces, 12.8ms
# Speed: 5.7ms preprocess, 12.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body142.png: 640x288 1 Face, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body143.png: 640x416 2 Faces, 11.2ms
# Speed: 3.2ms preprocess, 11.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body144.png: 640x512 1 Face, 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body145.png: 640x544 1 Face, 11.5ms
# Speed: 3.6ms preprocess, 11.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body146.png: 448x640 1 Face, 10.1ms
# Speed: 2.3ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body147.png: 480x640 1 Face, 10.2ms
# Speed: 2.3ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body148.png: 416x640 1 Face, 16.6ms
# Speed: 3.1ms preprocess, 16.6ms inference, 3.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body149.png: 480x640 1 Face, 9.9ms
# Speed: 3.1ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body15.png: 640x512 1 Face, 10.5ms
# Speed: 2.2ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body150.png: 640x384 1 Face, 16.5ms
# Speed: 3.3ms preprocess, 16.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body151.png: 640x576 1 Face, 11.6ms
# Speed: 4.0ms preprocess, 11.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body152.png: 640x544 2 Faces, 11.9ms
# Speed: 3.5ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body153.png: 640x416 1 Face, 9.1ms
# Speed: 2.7ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body154.png: 640x608 2 Faces, 12.0ms
# Speed: 4.4ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body155.png: 640x576 1 Face, 11.8ms
# Speed: 4.7ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body156.png: 640x544 2 Faces, 16.2ms
# Speed: 3.8ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body157.png: 608x640 2 Faces, 12.2ms
# Speed: 5.9ms preprocess, 12.2ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body158.png: 608x640 2 Faces, 11.3ms
# Speed: 4.2ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body159.png: 640x576 1 Face, 13.5ms
# Speed: 5.2ms preprocess, 13.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body16.png: 448x640 2 Faces, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body160.png: 576x640 2 Faces, 14.2ms
# Speed: 4.3ms preprocess, 14.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body161.png: 640x416 1 Face, 9.5ms
# Speed: 2.4ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body162.png: 640x608 2 Faces, 12.2ms
# Speed: 4.8ms preprocess, 12.2ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body163.png: 640x640 1 Face, 12.5ms
# Speed: 4.3ms preprocess, 12.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body164.png: 640x640 1 Face, 11.7ms
# Speed: 4.3ms preprocess, 11.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body165.png: 640x608 2 Faces, 12.3ms
# Speed: 4.3ms preprocess, 12.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body166.png: 640x576 1 Face, 12.9ms
# Speed: 4.2ms preprocess, 12.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body167.png: 640x640 1 Face, 12.8ms
# Speed: 5.3ms preprocess, 12.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body168.png: 640x512 2 Faces, 10.1ms
# Speed: 2.7ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body169.png: 576x640 1 Face, 12.1ms
# Speed: 3.7ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body17.png: 640x480 1 Face, 9.9ms
# Speed: 2.6ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body170.png: 544x640 1 Face, 11.4ms
# Speed: 3.5ms preprocess, 11.4ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body171.png: 640x576 1 Face, 11.6ms
# Speed: 5.3ms preprocess, 11.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body172.png: 640x320 (no detections), 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body173.png: 640x448 (no detections), 8.8ms
# Speed: 2.7ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body174.png: 608x640 (no detections), 11.7ms
# Speed: 4.7ms preprocess, 11.7ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body175.png: 640x544 2 Faces, 11.3ms
# Speed: 3.9ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body176.png: 640x416 1 Face, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body177.png: 576x640 1 Face, 11.3ms
# Speed: 4.2ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body178.png: 640x608 1 Face, 14.9ms
# Speed: 4.1ms preprocess, 14.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body179.png: 640x544 2 Faces, 10.4ms
# Speed: 3.2ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body18.png: 640x512 1 Face, 17.6ms
# Speed: 3.2ms preprocess, 17.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body180.png: 576x640 1 Face, 10.6ms
# Speed: 6.1ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body181.png: 640x544 2 Faces, 10.5ms
# Speed: 3.4ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body182.png: 640x544 1 Face, 9.3ms
# Speed: 3.1ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body183.png: 512x640 2 Faces, 9.5ms
# Speed: 2.5ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body184.png: 640x416 (no detections), 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body185.png: 544x640 1 Face, 10.8ms
# Speed: 3.1ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body186.png: 640x352 1 Face, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body187.png: 640x384 (no detections), 11.9ms
# Speed: 2.3ms preprocess, 11.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body188.png: 576x640 1 Face, 11.0ms
# Speed: 5.6ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body189.png: 640x352 1 Face, 10.5ms
# Speed: 2.1ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body19.png: 640x640 1 Face, 11.0ms
# Speed: 5.0ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body190.png: 640x640 1 Face, 10.4ms
# Speed: 4.2ms preprocess, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body191.png: 640x544 1 Face, 10.2ms
# Speed: 3.8ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body192.png: 640x352 (no detections), 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body193.png: 640x352 1 Face, 12.1ms
# Speed: 2.6ms preprocess, 12.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body194.png: 640x544 3 Faces, 11.2ms
# Speed: 3.4ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body195.png: 640x512 1 Face, 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body196.png: 640x512 1 Face, 8.3ms
# Speed: 2.3ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body197.png: 480x640 1 Face, 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body198.png: 640x416 1 Face, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body199.png: 640x288 1 Face, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body2.png: 640x480 1 Face, 11.3ms
# Speed: 3.3ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body20.png: 640x640 1 Face, 11.6ms
# Speed: 6.1ms preprocess, 11.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body200.png: 640x576 1 Face, 10.8ms
# Speed: 4.2ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body201.png: 640x320 1 Face, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body202.png: 640x480 1 Face, 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body203.png: 640x480 1 Face, 8.2ms
# Speed: 3.0ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body204.png: 640x640 1 Face, 11.6ms
# Speed: 5.0ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body205.png: 640x640 1 Face, 10.8ms
# Speed: 4.5ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body206.png: 640x576 1 Face, 10.6ms
# Speed: 3.6ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body207.png: 640x448 1 Face, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body208.png: 480x640 1 Face, 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body209.png: 576x640 (no detections), 10.4ms
# Speed: 3.7ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body21.png: 640x448 2 Faces, 8.4ms
# Speed: 2.3ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body210.png: 640x512 1 Face, 8.9ms
# Speed: 2.5ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body211.png: 544x640 2 Faces, 10.3ms
# Speed: 3.4ms preprocess, 10.3ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body212.png: 640x544 (no detections), 11.4ms
# Speed: 3.4ms preprocess, 11.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body213.png: 640x640 1 Face, 11.9ms
# Speed: 6.4ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body214.png: 640x512 1 Face, 9.5ms
# Speed: 2.7ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body215.png: 640x576 1 Face, 10.4ms
# Speed: 3.9ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body216.png: 544x640 1 Face, 10.5ms
# Speed: 4.0ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body217.png: 544x640 1 Face, 9.4ms
# Speed: 3.5ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body218.png: 384x640 2 Faces, 18.3ms
# Speed: 1.8ms preprocess, 18.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body219.png: 640x608 1 Face, 10.6ms
# Speed: 4.1ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body22.png: 640x448 2 Faces, 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body220.png: 544x640 1 Face, 10.4ms
# Speed: 4.6ms preprocess, 10.4ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body221.png: 640x384 1 Face, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body222.png: 640x416 1 Face, 18.6ms
# Speed: 2.2ms preprocess, 18.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body223.png: 640x384 1 Face, 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body224.png: 512x640 1 Face, 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body225.png: 640x416 1 Face, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body226.png: 640x448 (no detections), 13.9ms
# Speed: 2.8ms preprocess, 13.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body227.png: 640x416 1 Face, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body228.png: 544x640 1 Face, 10.2ms
# Speed: 3.2ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body229.png: 640x448 (no detections), 8.0ms
# Speed: 2.4ms preprocess, 8.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body23.png: 640x544 2 Faces, 17.0ms
# Speed: 3.3ms preprocess, 17.0ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body230.png: 640x320 1 Face, 8.7ms
# Speed: 3.3ms preprocess, 8.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body231.png: 544x640 1 Face, 10.4ms
# Speed: 4.4ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body232.png: 544x640 1 Face, 9.5ms
# Speed: 3.9ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body233.png: 512x640 2 Faces, 9.5ms
# Speed: 3.9ms preprocess, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body234.png: 640x384 1 Face, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body235.png: 640x256 1 Face, 8.6ms
# Speed: 1.6ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 256)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body236.png: 576x640 1 Face, 10.6ms
# Speed: 3.5ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body237.png: 416x640 2 Faces, 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body238.png: 640x352 1 Face, 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body239.png: 512x640 1 Face, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body24.png: 640x576 (no detections), 10.8ms
# Speed: 4.8ms preprocess, 10.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body240.png: 416x640 1 Face, 8.7ms
# Speed: 3.2ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body241.png: 448x640 1 Face, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body242.png: 640x608 1 Face, 10.8ms
# Speed: 4.1ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body243.png: 640x224 (no detections), 9.3ms
# Speed: 1.5ms preprocess, 9.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 224)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body244.png: 640x384 1 Face, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body245.png: 480x640 2 Faces, 8.6ms
# Speed: 2.6ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body246.png: 416x640 1 Face, 11.6ms
# Speed: 2.8ms preprocess, 11.6ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body247.png: 640x640 1 Face, 11.0ms
# Speed: 5.1ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body248.png: 640x384 1 Face, 18.0ms
# Speed: 2.3ms preprocess, 18.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body249.png: 640x224 1 Face, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 224)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body25.png: 640x480 (no detections), 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body250.png: 640x288 1 Face, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body251.png: 640x576 1 Face, 17.1ms
# Speed: 3.9ms preprocess, 17.1ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body252.png: 640x288 2 Faces, 8.4ms
# Speed: 1.3ms preprocess, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body253.png: 640x512 1 Face, 11.8ms
# Speed: 2.7ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body254.png: 640x448 1 Face, 9.7ms
# Speed: 2.5ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body255.png: 480x640 1 Face, 9.1ms
# Speed: 2.3ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body256.png: 640x576 1 Face, 10.7ms
# Speed: 3.7ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body257.png: 640x544 1 Face, 10.1ms
# Speed: 3.6ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body258.png: 640x608 2 Faces, 10.9ms
# Speed: 7.1ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body259.png: 640x352 1 Face, 18.9ms
# Speed: 2.1ms preprocess, 18.9ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body26.png: 576x640 1 Face, 10.7ms
# Speed: 5.4ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body260.png: 640x288 1 Face, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body261.png: 640x320 1 Face, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body262.png: 640x288 1 Face, 13.4ms
# Speed: 2.1ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body263.png: 448x640 1 Face, 17.7ms
# Speed: 3.2ms preprocess, 17.7ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body264.png: 544x640 3 Faces, 10.4ms
# Speed: 3.6ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body265.png: 640x640 1 Face, 12.7ms
# Speed: 4.6ms preprocess, 12.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body266.png: 608x640 1 Face, 10.9ms
# Speed: 4.6ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body267.png: 640x352 (no detections), 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body268.png: 640x480 1 Face, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body269.png: 320x640 (no detections), 10.0ms
# Speed: 1.7ms preprocess, 10.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body27.png: 640x384 (no detections), 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body270.png: 640x320 3 Faces, 8.6ms
# Speed: 2.8ms preprocess, 8.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body271.png: 576x640 (no detections), 10.7ms
# Speed: 4.7ms preprocess, 10.7ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body272.png: 640x320 1 Face, 8.3ms
# Speed: 3.4ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body273.png: 640x480 1 Face, 12.0ms
# Speed: 4.3ms preprocess, 12.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body274.png: 640x480 1 Face, 8.3ms
# Speed: 3.1ms preprocess, 8.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body275.png: 640x224 1 Face, 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 224)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body276.png: 640x384 1 Face, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# ...
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body4.png: 448x640 1 Face, 9.7ms
# Speed: 3.3ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body40.png: 640x448 1 Face, 10.0ms
# Speed: 4.7ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body41.png: 640x608 2 Faces, 11.4ms
# Speed: 4.2ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body42.png: 640x448 1 Face, 11.8ms
# Speed: 3.6ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body43.png: 640x384 1 Face, 8.8ms
# Speed: 2.4ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body44.png: 640x416 1 Face, 8.7ms
# Speed: 2.6ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body45.png: 320x640 1 Face, 11.4ms
# Speed: 2.1ms preprocess, 11.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body46.png: 640x448 (no detections), 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body47.png: 576x640 1 Face, 12.2ms
# Speed: 4.2ms preprocess, 12.2ms inference, 3.3ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body48.png: 640x544 2 Faces, 11.1ms
# Speed: 3.9ms preprocess, 11.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body49.png: 640x640 (no detections), 11.6ms
# Speed: 5.0ms preprocess, 11.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body5.png: 640x640 1 Face, 10.5ms
# Speed: 5.6ms preprocess, 10.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body50.png: 384x640 (no detections), 12.0ms
# Speed: 3.4ms preprocess, 12.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body51.png: 640x576 1 Face, 10.7ms
# Speed: 5.3ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body52.png: 544x640 (no detections), 10.8ms
# Speed: 4.3ms preprocess, 10.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body53.png: 512x640 1 Face, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body54.png: 640x352 1 Face, 19.5ms
# Speed: 2.0ms preprocess, 19.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body55.png: 576x640 1 Face, 18.8ms
# Speed: 5.1ms preprocess, 18.8ms inference, 3.0ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body56.png: 640x480 1 Face, 13.5ms
# Speed: 3.7ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body57.png: 640x640 1 Face, 11.4ms
# Speed: 5.4ms preprocess, 11.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body58.png: 608x640 (no detections), 11.4ms
# Speed: 5.8ms preprocess, 11.4ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body59.png: 544x640 1 Face, 13.0ms
# Speed: 4.4ms preprocess, 13.0ms inference, 2.4ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body6.png: 480x640 1 Face, 8.9ms
# Speed: 2.8ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body60.png: 640x384 1 Face, 20.9ms
# Speed: 2.1ms preprocess, 20.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body61.png: 640x640 2 Faces, 11.6ms
# Speed: 6.1ms preprocess, 11.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body62.png: 544x640 1 Face, 12.2ms
# Speed: 4.1ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body63.png: 480x640 1 Face, 8.9ms
# Speed: 3.4ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body64.png: 480x640 2 Faces, 19.2ms
# Speed: 2.9ms preprocess, 19.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body65.png: 640x448 1 Face, 9.4ms
# Speed: 3.0ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body66.png: 640x576 1 Face, 11.5ms
# Speed: 5.7ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body67.png: 640x512 1 Face, 11.9ms
# Speed: 3.8ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body68.png: 640x640 1 Face, 11.5ms
# Speed: 6.2ms preprocess, 11.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body69.png: 640x512 (no detections), 13.1ms
# Speed: 2.6ms preprocess, 13.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body7.png: 512x640 1 Face, 11.5ms
# Speed: 3.2ms preprocess, 11.5ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body70.png: 288x640 (no detections), 14.6ms
# Speed: 2.4ms preprocess, 14.6ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body71.png: 448x640 1 Face, 16.7ms
# Speed: 3.6ms preprocess, 16.7ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body72.png: 640x480 1 Face, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body73.png: 608x640 1 Face, 11.2ms
# Speed: 4.7ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body74.png: 640x384 1 Face, 17.4ms
# Speed: 3.7ms preprocess, 17.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body75.png: 640x384 (no detections), 14.1ms
# Speed: 2.6ms preprocess, 14.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body76.png: 640x448 1 Face, 12.9ms
# Speed: 2.1ms preprocess, 12.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body77.png: 640x576 1 Face, 10.6ms
# Speed: 4.5ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body78.png: 544x640 1 Face, 10.7ms
# Speed: 3.1ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body79.png: 576x640 2 Faces, 10.8ms
# Speed: 8.1ms preprocess, 10.8ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body8.png: 640x480 1 Face, 20.6ms
# Speed: 2.3ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body80.png: 640x640 1 Face, 11.4ms
# Speed: 4.6ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body81.png: 640x416 (no detections), 21.1ms
# Speed: 2.4ms preprocess, 21.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body82.png: 640x480 1 Face, 10.9ms
# Speed: 4.6ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body83.png: 640x384 1 Face, 12.6ms
# Speed: 2.7ms preprocess, 12.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body84.png: 640x416 (no detections), 9.4ms
# Speed: 2.6ms preprocess, 9.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body85.png: 640x480 1 Face, 18.8ms
# Speed: 3.2ms preprocess, 18.8ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body86.png: 640x480 1 Face, 21.2ms
# Speed: 3.2ms preprocess, 21.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body87.png: 448x640 2 Faces, 13.9ms
# Speed: 2.9ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body88.png: 640x640 1 Face, 11.4ms
# Speed: 5.5ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body89.png: 640x480 2 Faces, 9.0ms
# Speed: 2.2ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body9.png: 480x640 1 Face, 18.3ms
# Speed: 4.1ms preprocess, 18.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body90.png: 640x512 1 Face, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body91.png: 640x640 1 Face, 11.9ms
# Speed: 6.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body92.png: 640x640 2 Faces, 11.0ms
# Speed: 5.9ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body93.png: 608x640 1 Face, 11.3ms
# Speed: 4.4ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body94.png: 640x608 1 Face, 12.0ms
# Speed: 6.2ms preprocess, 12.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body95.png: 640x640 2 Faces, 12.1ms
# Speed: 5.4ms preprocess, 12.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body96.png: 640x640 1 Face, 11.2ms
# Speed: 4.7ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body97.png: 640x608 (no detections), 11.5ms
# Speed: 4.2ms preprocess, 11.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body98.png: 640x640 1 Face, 12.0ms
# Speed: 5.2ms preprocess, 12.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\julie\OneDrive - UCL\Master_2\Mmoire\Chimprec Dataset\face_detection_test_dataset\images\body99.png: 576x640 1 Face, 17.0ms
# Speed: 4.3ms preprocess, 17.0ms inference, 2.6ms postprocess per image at shape (1, 3, 576, 640)

# %%
# Sort data by t values
sorted_data = sorted(data.items())  
t_values, pr_recall = zip(*sorted_data)

# Extract precision and recall
precision_values, recall_values = zip(*pr_recall)

# Create the plot
plt.figure(figsize=(10, 5))
plt.plot(t_values, precision_values, label="Precision", color="peru", marker='o', linestyle='-')
plt.plot(t_values, recall_values, label="Recall", color="maroon", marker='s', linestyle='-')

# Labels and title
plt.xlabel("Confidence threshold")
plt.ylabel("Value")
plt.title(f"Precision and Recall as a function of the confidence threshold (iou_t = {t}) (face detection)")
plt.legend()
plt.grid(True)

# Set x-axis ticks to show all t values
plt.xticks(t_values, labels=[str(t) for t in t_values])  # Ensuring each t is explicitly labeled

# Display the plot
#plt.savefig("plots/PR_according_to_CT_face.svg", format="svg")
plt.show()

n_gt = 0
for values in GT.values():
    n_gt += len(values)

# Create the plot
plt.figure(figsize=(10, 5))
plt.plot(t_values, [i/n_gt for i in n_pred_list], label="ratio n_pred/n_gt", color="indigo", marker='o', linestyle='-')
plt.axhline(y=1, color='red', linestyle='--', linewidth=2, label="y = 1")

# Labels and title
plt.xlabel("Confidence threshold")
plt.ylabel("#pred / #ground truth")
plt.title(f"# predicted bboxes over # ground truth bboxes as a function of the confidence threshold (face detection)")
plt.grid(True)

# Set x-axis ticks to show all t values
plt.xticks(t_values, labels=[str(t) for t in t_values])  # Ensuring each t is explicitly labeled

# Display the plot
#plt.savefig("plots/n_pred_over_n_gt_face.svg", format="svg")
plt.show()

# %%
best_matches = []
# Iterate over all unique image names in ground truths and predictions
for image_name in set(GT.keys()).union(predictions.keys()):
    gt_bboxes = GT.get(image_name, [])  # Retrieve ground truth bboxes (default empty list if missing)
    pred_bboxes = predictions.get(image_name, [])  # Retrieve predicted bboxes (default empty list if missing)
    
    # Iterate over each predicted bounding box
    for pred in pred_bboxes:
        best_iou = 0  # Initialize the best IoU score for the current prediction
        
        # Compare prediction with each ground truth bbox
        for gt in gt_bboxes:
            score = iou(pred, gt)  # Compute IoU
            if score > best_iou:  # Update best match if IoU is higher
                best_iou = score

        best_matches.append(best_iou)

# Plot histogram instead of KDE
plt.figure(figsize=(10, 5))
plt.hist(best_matches, bins=50, color="limegreen", edgecolor="darkgreen", alpha=0.7)

plt.axvline(x=t, color='red', linestyle='--', linewidth=2, label=f"Threshold ({t})")

# Labels and title
plt.xlabel("Best IOU matches")
plt.ylabel("Number of Matches")
plt.title("Distribution of the best IOU matches between ground truth and predicted bboxes (face detection)")
plt.xlim(0, 1)  # Ensuring the range stays between 0 and 1
plt.grid(True)

# Add legend
plt.legend(loc="upper left")

# Save and show the plot
#plt.savefig("plots/best_matches_distribution_face.svg", format="svg")
plt.show()

# %%
draw_predictions(predictions, GT, test_set, "visualisation")
