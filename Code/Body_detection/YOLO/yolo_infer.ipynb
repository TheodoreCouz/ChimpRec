# %%
import os
from ultralytics import YOLO
import cv2

# %%
video_path = "C:/Users/julie/OneDrive - UCL/Master_2/Mémoire/Chimprec Dataset/Videos/Identification/Collective/20241218 - 12h42.MP4"
#video_path = "C:/Users/julie/Documents/Unif/Mémoire/Test_video.mp4"
#video_path = "C:/Users/julie/OneDrive - UCL/Master_2/Mémoire/video_chimp/WhatsApp Video 2024-10-04 at 08.35.55.mp4"
video_path_out = 'C:/Users/julie/Documents/Unif/Mémoire/YOLO_body/out6.mp4'

# %%
# video_path = "/home/theo/Documents/Unif/Master/ChimpRec/Code/Superpixel R-CNN/Video/Video_1.mp4"
# video_path = "/home/theo/Documents/Unif/Master/ChimpRec-Datasets/ChimpBehave/chimpbehave/original/Colebe4_241_325.mp4"

# video_path = "/home/theo/Documents/Unif/Master/ChimpRec-Datasets/Videos chimprec/penda7.mp4"
# video_path = "/home/theo/Documents/Unif/Master/ChimpRec/ChimpRec-Dataset/Our_data/Videos/Video_1.mp4"
# video_path = "/home/theo/Documents/Unif/Master/ChimpRec-Datasets/Videos chimprec/WhatsApp Video 2024-10-04 at 08.35.55.mp4"
# video_path_out = 'C:/Users/julie/Documents/Unif/Mémoire/YOLO_body/out2.mp4'

# %%
cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()
H, W, _ = frame.shape
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))


model_version = "train9"
model_path = f"C:/Users/julie/Documents/Unif/Mémoire/YOLO_body/runs/detect/{model_version}/weights/best.pt"

# Load a model
model = YOLO(model_path)  # load a custom model

threshold = 0.5

while ret:

    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, f"{results.names[int(class_id)].upper()}: {round(score, 3)}", (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 Bodys, 35.2ms
# Speed: 3.4ms preprocess, 35.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Bodys, 34.7ms
# Speed: 3.5ms preprocess, 34.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Bodys, 25.8ms
# Speed: 2.1ms preprocess, 25.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Bodys, 17.8ms
# Speed: 2.3ms preprocess, 17.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Bodys, 17.4ms
# Speed: 3.3ms preprocess, 17.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Bodys, 21.5ms
# Speed: 3.2ms preprocess, 21.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bodys, 16.6ms
# Speed: 3.6ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Bodys, 16.8ms
# ...
