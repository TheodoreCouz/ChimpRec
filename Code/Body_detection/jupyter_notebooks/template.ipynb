# %%
import cv2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import torchvision
import torch
from ultralytics import YOLO

COCO_INSTANCE_CATEGORY_NAMES = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant',
    'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A', 'handbag',
    'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat',
    'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'N/A', 'wine glass',
    'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli',
    'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
    'N/A', 'dining table', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard',
    'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book', 'clock',
    'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

# %%
def show_images(images, titles):
    n = len(images)

    fig, axes = plt.subplots(1, n, figsize=(5 * n, 5))
    if n == 1: axes = [axes]

    for i, ax in enumerate(axes):
        if len(images[i].shape) == 3: 
            bgr_image = cv2.cvtColor(images[i], cv2.COLOR_RGB2BGR)
            ax.imshow(bgr_image)
            # the title of this subfigure is titles[i]
        else: ax.imshow(images[i], cmap='gray')
        
        ax.set_title(titles[i])
        ax.axis('off')

    plt.show()

# %%
def load_model():
    pass

def get_model(model_name):
    return load_model()

# %%
def detect_individuals(image, threshold=0.001):
    return

# %%
def draw_boxes(image, boxes):
    """
    Draw the bounding boxes on the frame.
    :param frame: The image frame.
    :param boxes: A list of bounding boxes. Each bounding box can be either (x, y, w, h) or (x, y, size).
    :return: The frame with the boxes drawn on it.
    """
    boxed_image = image
    for box in boxes:


        # Ensure coordinates are integers
        x1, y1, x2, y2 = box

        # Draw the rectangle on the frame
        cv2.rectangle(boxed_image, (x1, y1), (x2, y2), (255, 0, 0), 3)

    return boxed_image

# %%
# Main function to process a single image
def process_image(input_image_path):
    # Load the image
    image = cv2.imread(input_image_path)
    if image is None:
        raise ValueError(f"Image at path {input_image_path} could not be loaded.")

    boxes = detect_individuals(image)
    annotated_image = draw_boxes(image, boxes)

    return annotated_image

# %%
input_image_path = "/home/theo/Documents/Unif/Master/ChimpRec/Code/Test - images"
model_name = "megadetector"

# %%
for i in range(1, 13):
    path_blank = f"{input_image_path}/blank/{i}.png"
    path_ground_truth = f"{input_image_path}/ground truth/{i}.png"
    img_pred = process_image(path_blank)
    img_ground_truth = cv2.imread(path_ground_truth)
    show_images(
        [img_pred, img_ground_truth],
        ["YOLO v8s", "Ground Truth"])
# Out:
# 0: 640x384 (no detections), 52.8ms
# Speed: 1.9ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 1 elephant, 48.2ms
# Speed: 1.4ms preprocess, 48.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# /tmp/ipykernel_186297/3834614060.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   if confidence >= threshold and int(class_id) == 0:  # Assuming '0' is the class ID for animals
# 0: 640x384 (no detections), 46.1ms
# Speed: 1.5ms preprocess, 46.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 bear, 59.5ms
# Speed: 1.6ms preprocess, 59.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 1 car, 55.0ms
# Speed: 1.7ms preprocess, 55.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 (no detections), 57.0ms
# Speed: 1.3ms preprocess, 57.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 elephant, 3 bears, 57.3ms
# Speed: 1.7ms preprocess, 57.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 2 bears, 57.7ms
# Speed: 1.5ms preprocess, 57.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 2 persons, 2 bears, 59.4ms
# Speed: 1.5ms preprocess, 59.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 2 persons, 55.2ms
# Speed: 1.9ms preprocess, 55.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 (no detections), 62.6ms
# Speed: 2.1ms preprocess, 62.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 5 birds, 56.8ms
# Speed: 1.9ms preprocess, 56.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
