# %% [markdown]
# <h2>Imports</h2>

# %%
import os
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
import seaborn as sns

test_set = "/home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set"
model_path = "/home/theo/Documents/Unif/Master/ChimpRec/Code/Face_detection/runs/detect/train3/weights/best.pt"
# test_set = "C:/Users/julie/OneDrive - UCL/Master_2/Mémoire/Chimprec Dataset/ChimpRec Detection/Test set"
# model_path = "C:/Users/julie/OneDrive - UCL/Master_2/Mémoire/ChimpRec/Code/Body_detection/YOLO_small/runs/detect/train9/weights/best.pt"

def yolo_to_relative_coord(bbox, img_dim):
    """
    Compute the coordinates of the bbox in pixels term.

    Args:
        bbox(tuple): Bbox in YOLO format.
        img_dim (tuple): Dimension of the image.

    Returns:
        tuple: The coordinate of the top left an the bottom right corner of the bbox in pixel term.
    """ 
    x_center, y_center, width, height = bbox
    img_w, img_h = img_dim
    
    x_min = (x_center - width / 2) * img_w
    y_min = (y_center - height / 2) * img_h
    x_max = (x_center + width / 2) * img_w
    y_max = (y_center + height / 2) * img_h
    
    return [x_min, y_min, x_max, y_max]

def convert_to_yolo(bbox, img_dim=(1080, 1920)):
    """
    Compute the coordinates of the bbox in pixels term.

    Args:
        bbox(tuple): Cordinate of the top left an the bottom right corner of the bbox in pixel term..
        img_dim (tuple): Dimension of the image.

    Returns:
        tuple: The coordinate of the bbox in YOLO format ([x_center, y_center, width, height]).
    """
    x1, y1, x2, y2 = bbox
    img_width, img_height = img_dim

    # Compute center coordinates
    x_center = (x1 + x2) / 2.0
    y_center = (y1 + y2) / 2.0

    # Compute width and height
    width = x2 - x1
    height = y2 - y1

    # Normalize values by image dimensions
    x_center /= img_width
    y_center /= img_height
    width /= img_width
    height /= img_height

    return [x_center, y_center, width, height]

def get_intersection(bbox1, bbox2, img_dim):
    """
    Compute the intersection of two bboxes.

    Args:
        bbox1, bbox2 (tuple): Two bboxes in YOLO format.
        img_dim (tuple): Dimension of the image.

    Returns:
        int: Value of the intersection of the two bboxes.
    """ 
    # conversion into relative coordinates
    Ax, Ay, Bx, By = yolo_to_relative_coord(bbox1, img_dim)
    Cx, Cy, Dx, Dy = yolo_to_relative_coord(bbox2, img_dim)

    # computation of the intersection
    x_overlap = min(Dx, Bx) - max(Ax, Cx)
    y_overlap = min(Dy, By) - max(Ay, Cy)
    if (x_overlap < 0 or y_overlap < 0): return 0 # no overlap case
    return x_overlap*y_overlap

def get_union(bbox1, bbox2, img_dim, intersection): 
    """
    Compute the union of two bboxes.

    Args:
        bbox1, bbox2 (tuple): Two bboxes in YOLO format.
        img_dim (tuple): Dimension of the image.
        intersection (int): Value of the intesection of the two bboxes.

    Returns:
        int: Value of the union of the two bboxes.
    """
    # conversion into relative coordinates
    Ax, Ay, Bx, By = yolo_to_relative_coord(bbox1, img_dim)
    Cx, Cy, Dx, Dy = yolo_to_relative_coord(bbox2, img_dim)

    # computation of the union
    area_1 = abs((Bx-Ax)*(By-Ay))
    area_2 = abs((Dx-Cx)*(Dy-Cy))
    return area_1 + area_2 - intersection


def iou(bbox1, bbox2, img_dim=(1080, 1920)):
    """
    Compute the iou of two bboxes.

    Args:
        bbox1, bbox2 (tuple): Two bboxes in YOLO format.
        img_dim (tuple): Dimension of the image.

    Returns:
        int: The intersection over union metric between bbox1 and bbox2.
    """
    intersection = get_intersection(bbox1, bbox2, img_dim)
    union = get_union(bbox1, bbox2, img_dim, intersection)
    # IoU
    return intersection/union

"""
The arguments <ground_truths> and <predictions> are expected to be 
python dictionaries structured as follows:

    dictionnary {
        image_name 1: [
                bbox 1,
                bbox 2, 
                ...
            ],
        image_name 2: [
                bbox 1,
                bbox 2, 
                ...
            ],
        ...
    }

PS: the bounding boxes are expected to be encoded in YOLO format.

    
For each image, every prediction bbox will be 
compared to every ground truth bbox to find the best match.

If a ground truth bbox finds no match among the prediction bbox:
+1 false negative

If a prediction bbox finds no match among the ground truth bbox:
+1 false positive

If the best match between a prediction bbox and the ground truth
bboxes has a low IoU (bellow a given threshold <t>):
+1 false positive

If a prediction bbox best match in the ground truth bboxes has
already been matched by another prediction bbox with a greater score:
+1 false positive

If the best match between a prediction bbox and the ground truth
bboxes has a high IoU (above a given threshold <t>):
+1 true positive

The true negative won't be counted because it means that no
prediction bbox has been found in the background. This is nonsense to count this.
"""
def extract_metrics(ground_truths:dict, predictions:dict, t=0.75):
    tp, fp, fn = 0, 0, 0  # Initialize counters for TP, FP, and FN
    
    # Iterate over all unique image names in ground truths and predictions
    for image_name in set(ground_truths.keys()).union(predictions.keys()):
        gt_bboxes = ground_truths.get(image_name, [])  # Retrieve ground truth bboxes (default empty list if missing)
        pred_bboxes = predictions.get(image_name, [])  # Retrieve predicted bboxes (default empty list if missing)
        
        matched_gt = set()  # Store indices of matched ground truth bboxes
        pred_matched_scores = []  # Keep track of IoU scores of matched predictions
        
        # Iterate over each predicted bounding box
        for pred in pred_bboxes:
            best_iou = 0  # Initialize the best IoU score for the current prediction
            best_gt_idx = -1  # Index of the best-matching ground truth bbox
            
            # Compare prediction with each ground truth bbox
            for i, gt in enumerate(gt_bboxes):
                score = iou(pred, gt)  # Compute IoU
                if score > best_iou:  # Update best match if IoU is higher
                    best_iou = score
                    best_gt_idx = i
            
            # Determine if the prediction is a TP or FP based on IoU and previous matches
            if best_iou >= t and best_gt_idx not in matched_gt:
                matched_gt.add(best_gt_idx)  # Mark ground truth bbox as matched
                pred_matched_scores.append(best_iou)  # Store IoU score
                tp += 1
            else:
                fp += 1
        
        # Count False Negatives (ground truths that were not matched)
        fn += len(gt_bboxes) - len(matched_gt)
    
    return {"true_positives": tp, "false_positives": fp, "false_negatives": fn}

def extract_ground_truth(test_set_path = test_set):
    path = f'{test_set_path}/labels'
    data = dict()

    # check whether the specified path is valid directory
    if not os.path.isdir(path):
        print(f"Error: {path} is not a valid directory.")
        return
    
    for textfile in os.listdir(path):
        file_path = f"{path}/{textfile}"

        # check whether textfile exists in the folder located at the specified path
        if os.path.isfile(file_path):
            data[textfile.strip(".txt")] = []

            # open the file in read mode
            with open(file_path, 'r') as file:

                # extract the bounding boxes one by one
                for line in file.readlines():
                    splitted = line.split(" ")
                    detection_class = splitted[0]
                    bbox = splitted[1:]
                    for i in range(len(bbox)): bbox[i] = float(bbox[i].strip("/n"))
                    data[textfile.strip(".txt")].append(bbox)
                file.close()
    
    return data

def predict(model_path, test_set_path, t_confidence = 0.4):
    """
    Predict bounding boxes using a YOLO model.

    Args:
        model_path (str): Path to the YOLO model.
        test_set_path (str): Path to the test set directory.

    Returns:
        dict: Dictionary with image prefixes as keys and predicted bounding boxes (YOLO format).
    """
    predictions = dict()

    # Load the YOLO model
    model = YOLO(model_path)

    test_set_path = f"{test_set_path}/images"

    # Ensure the test set path exists
    if not os.path.isdir(test_set_path):
        print(f"Error: Test set directory '{test_set_path}' not found.")
        return {}

    # Iterate over all images in the test set directory
    image_extension = ".png"
    for filename in sorted(os.listdir(test_set_path)):
        file_path = os.path.join(test_set_path, filename)

        # Check if the file is an image
        if not filename.lower().endswith(image_extension):
            continue

        filename_prefix = filename.split(".")[0]
        predictions[filename_prefix] = []

        # Run inference
        results = model(file_path)[0]

        # Extract YOLO format bounding boxes
        img = cv2.imread(file_path)
        img_height, img_width, _ = img.shape

        for result in results.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = result

            if score < t_confidence: continue

            # Convert bbox to YOLO format (normalized)
            x_center = ((x1 + x2) / 2) / img_width
            y_center = ((y1 + y2) / 2) / img_height
            width = (x2 - x1) / img_width
            height = (y2 - y1) / img_height

            predictions[filename_prefix].append((x_center, y_center, width, height))

    return predictions

def merge_boxes(predictions, merging_threshold, img_dim=(1080, 1920)):
    """
    Merge the bboxes that overlap too much.

    Args:
        predictions (dict): Dict of the predicted bboxes for each image of the dataset.
        merging_threshold (float): Minimum proportion of overlap needed to merge two bboxes.
        img_dim (tuple): Dimension of the image.

    Returns:
        dict: Dictionary with image prefixes as keys and predicted bounding boxes (YOLO format) merged when needed.
    """
    new_dict_predictions = {}
    for file in predictions: 
        new_predictions = []
        prediction = predictions[file]

        for pred1 in prediction: 
            Ax, Ay, Bx, By = yolo_to_relative_coord(pred1, img_dim)
            area1 = (Bx - Ax) * (By - Ay)

            for pred2 in new_predictions: 
                inter = get_intersection(pred1, pred2, img_dim)
                
                Cx, Cy, Dx, Dy = yolo_to_relative_coord(pred2, img_dim)
                area2 = (Dx - Cx) * (Dy - Cy)
                if inter / area1 > merging_threshold or inter / area2 > merging_threshold:        
                    # Fusion des coordonnées
                    Ax, Ay = min(Ax, Cx), min(Ay, Cy)
                    Bx, By = max(Bx, Dx), max(By, Dy)
                    new_predictions.remove(pred2)
            new_predictions.append(tuple(convert_to_yolo((Ax, Ay, Bx, By), img_dim)))
        new_dict_predictions[file] = new_predictions
    return new_dict_predictions

def draw_predictions(predictions, ground_truth, test_set_path, output_folder):
    """
    Draws predicted and ground truth bounding boxes on images and displays them in Jupyter Notebook.

    Args:
        predictions (dict): Dictionary of predicted bounding boxes in YOLO format.
        ground_truth (dict): Dictionary of ground truth bounding boxes in YOLO format.
        test_set_path (str): Path to the test set directory.

    Returns:
        None
    """
    test_set_path = f"{test_set_path}/images"

    for img_prefix, pred_bboxes in predictions.items():
        img_name = f"{img_prefix}.png"
        img_path = os.path.join(test_set_path, img_name)
        output_path = os.path.join(output_folder, img_name)

        # Load image
        image = cv2.imread(img_path)
        if image is None:
            print(f"Error: Unable to load image {img_name}")
            continue

        # Convert from BGR to RGB for correct color display
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        img_height, img_width, _ = image.shape

        def draw_bbox(image, bbox, color, label=None):
            """ Draws a single bounding box on the image. """
            x_center, y_center, width, height = bbox

            # Convert YOLO format to absolute pixel coordinates
            x1 = int((x_center - width / 2) * img_width)
            y1 = int((y_center - height / 2) * img_height)
            x2 = int((x_center + width / 2) * img_width)
            y2 = int((y_center + height / 2) * img_height)

            # Draw rectangle
            cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)

            # Put label
            if label:
                font = cv2.FONT_HERSHEY_SIMPLEX
                font_scale = 0.5
                thickness = 1
                cv2.putText(image, label, (x1, max(y1 - 5, 10)), font, font_scale, color, thickness, cv2.LINE_AA)

        # Draw ground truth boxes (green)
        if img_prefix in ground_truth:
            for bbox in ground_truth[img_prefix]:
                draw_bbox(image, bbox, (0, 255, 0))  # Class label only

        # Draw predicted boxes (blue)
        for bbox in pred_bboxes:
            draw_bbox(image, bbox, (255, 0, 0), f"P {int(bbox[0])}")  # Class & confidence

        image_bgr = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        cv2.imwrite(output_path, image_bgr)

# %% [markdown]
# <h1>Effective code</h1>

# %% [markdown]
# <h3>Ground truth extraction.</h3>

# %%
t = 0.6
t_confidence = 0.35
merging_threshold = 0.8

GT = extract_ground_truth()
predictions = predict(model_path, test_set, t_confidence=t_confidence)
merged_predictions = merge_boxes(predictions, merging_threshold)
predictions = merged_predictions
# Out:
# {'body0': [[0.11977573904179409, 0.2578616352201258, 0.23955147808358818, 0.5094339622641509]], 'body1': [[0.6205821205821206, 0.2167056074766355, 0.26195426195426197, 0.4030373831775701]], 'body10': [[0.841875, 0.6276202219482121, 0.31625, 0.5277435265104808]], 'body100': [[0.5872093023255814, 0.43703703703703706, 0.5166112956810631, 0.30925925925925923]], 'body101': [[0.5914760914760915, 0.3413793103448276, 0.47193347193347196, 0.33793103448275863]], 'body102': [[0.7338403041825095, 0.21450151057401812, 0.2864385297845374, 0.41389728096676737]], 'body103': [[0.7791798107255521, 0.3435185185185185, 0.4416403785488959, 0.30185185185185187]], 'body104': [[0.476905311778291, 0.26285714285714284, 0.5889145496535797, 0.5257142857142857]], 'body105': [[0.3739406779661017, 0.21417682926829268, 0.4258474576271186, 0.4253048780487805]], 'body106': [[0.3531669865642994, 0.2703125, 0.510556621880998, 0.278125]], 'body107': [[0.5841121495327103, 0.2956403269754768, 0.6884735202492211, 0.37329700272479566]], 'body108': [[0.5, 0.2435344827586207, 0.5010060362173038, 0.4827586206896552]], 'body109': [[0.4731977818853974, 0.21354166666666666, 0.5175600739371534, 0.41220238095238093]], 'body11': [[0.5560165975103735, 0.25261324041811845, 0.603042876901798, 0.47735191637630664]], 'body110': [[0.5208747514910537, 0.29282868525896416, 0.5685884691848907, 0.5418326693227091]], 'body111': [[0.494336569579288, 0.24295774647887325, 0.4967637540453074, 0.4647887323943662]], 'body112': [[0.654320987654321, 0.1977491961414791, 0.5020576131687243, 0.3954983922829582]], 'body113': [[0.6842105263157895, 0.23667205169628433, 0.5910931174089069, 0.45718901453957994]], 'body114': [[0.16311659192825112, 0.25, 0.3239910313901345, 0.49007444168734493]], 'body115': [[0.421505376344086, 0.2048, 0.443010752688172, 0.4096]], 'body116': [[0.5228013029315961, 0.15944055944055943, 0.7915309446254072, 0.31888111888111886]], 'body117': [[0.27616926503340755, 0.3066225165562914, 0.42316258351893093, 0.295364238410596]], 'body118': [[0.2912801484230056, 0.21486486486486486, 0.48608534322820035, 0.40540540540540543]], 'body119': [[0.3730964467005076, 0.2480544747081712, 0.32656514382402707, 0.4766536964980545]], 'body12': [[0.26973684210526316, 0.21100917431192662, 0.4517543859649123, 0.3853211009174312]], 'body120': [[0.4774774774774775, 0.21837708830548927, 0.5165165165165165, 0.4224343675417661]], 'body121': [[0.3984848484848485, 0.2199017199017199, 0.4636363636363636, 0.42997542997543]], 'body122': [[0.6988505747126437, 0.13316582914572864, 0.30344827586206896, 0.2629815745393635]], 'body123': [[0.34918032786885245, 0.18863636363636363, 0.3770491803278688, 0.3409090909090909]], 'body124': [[0.7623655913978494, 0.21571648690292758, 0.3548387096774194, 0.4067796610169492]], 'body125': [[0.3115482233502538, 0.33893280632411066, 0.37182741116751267, 0.6620553359683794]], 'body126': [[0.8584070796460177, 0.17794486215538846, 0.2713864306784661, 0.3458646616541353]], 'body127': [[0.21216617210682492, 0.18365180467091294, 0.4065281899109792, 0.35456475583864117]], 'body128': [[0.1390728476821192, 0.1910828025477707, 0.2737306843267108, 0.36942675159235666]], 'body129': [[0.33471933471933474, 0.22253787878787878, 0.35343035343035345, 0.4337121212121212]], 'body13': [[0.6726190476190477, 0.18907563025210083, 0.39285714285714285, 0.3445378151260504]], 'body130': [[0.5316129032258065, 0.2625979843225084, 0.38193548387096776, 0.3594624860022396]], 'body131': [[0.5582627118644068, 0.2028301886792453, 0.4046610169491525, 0.39433962264150946]], 'body132': [[0.573170731707317, 0.17729083665338646, 0.3924611973392461, 0.3466135458167331]], 'body133': [[0.48826979472140764, 0.5993788819875776, 0.4252199413489736, 0.2329192546583851]], 'body134': [[0.22238372093023256, 0.2348942598187311, 0.438953488372093, 0.4697885196374622]], 'body135': [[0.34301732925586137, 0.45766773162939295, 0.3781855249745158, 0.547923322683706]], 'body136': [[0.3351190476190476, 0.22027439024390244, 0.313095238 ...
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body0.png: 416x640 1 Face, 58.7ms
# Speed: 1.2ms preprocess, 58.7ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body1.png: 576x640 1 Face, 86.2ms
# Speed: 1.6ms preprocess, 86.2ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body10.png: 640x640 2 Faces, 95.9ms
# Speed: 2.4ms preprocess, 95.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body100.png: 640x384 1 Face, 80.6ms
# Speed: 1.9ms preprocess, 80.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body101.png: 640x448 2 Faces, 70.1ms
# Speed: 1.5ms preprocess, 70.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body102.png: 544x640 1 Face, 109.6ms
# Speed: 1.8ms preprocess, 109.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body103.png: 640x384 1 Face, 84.8ms
# Speed: 1.9ms preprocess, 84.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body104.png: 544x640 2 Faces, 88.9ms
# Speed: 1.5ms preprocess, 88.9ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body105.png: 640x480 2 Faces, 73.5ms
# Speed: 1.2ms preprocess, 73.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body106.png: 640x352 1 Face, 93.1ms
# Speed: 1.5ms preprocess, 93.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body107.png: 640x288 1 Face, 47.8ms
# Speed: 0.8ms preprocess, 47.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body108.png: 608x640 2 Faces, 106.6ms
# Speed: 1.9ms preprocess, 106.6ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body109.png: 640x544 2 Faces, 79.1ms
# Speed: 1.5ms preprocess, 79.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body11.png: 640x544 1 Face, 85.0ms
# Speed: 1.9ms preprocess, 85.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body110.png: 640x640 3 Faces, 92.9ms
# Speed: 1.5ms preprocess, 92.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body111.png: 608x640 1 Face, 81.9ms
# Speed: 1.3ms preprocess, 81.9ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body112.png: 640x512 2 Faces, 91.9ms
# Speed: 1.2ms preprocess, 91.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body113.png: 640x256 1 Face, 58.5ms
# Speed: 1.0ms preprocess, 58.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 256)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body114.png: 608x640 1 Face, 97.5ms
# Speed: 1.8ms preprocess, 97.5ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body115.png: 640x480 1 Face, 81.7ms
# Speed: 1.4ms preprocess, 81.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body116.png: 640x288 1 Face, 46.1ms
# Speed: 1.2ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body117.png: 640x384 1 Face, 53.3ms
# Speed: 1.2ms preprocess, 53.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body118.png: 640x480 1 Face, 72.8ms
# Speed: 1.3ms preprocess, 72.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body119.png: 576x640 1 Face, 79.2ms
# Speed: 1.3ms preprocess, 79.2ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body12.png: 640x640 1 Face, 90.5ms
# Speed: 1.8ms preprocess, 90.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body120.png: 640x512 1 Face, 74.4ms
# Speed: 1.4ms preprocess, 74.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body121.png: 640x544 1 Face, 80.8ms
# Speed: 1.9ms preprocess, 80.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body122.png: 640x480 1 Face, 64.3ms
# Speed: 1.3ms preprocess, 64.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body123.png: 640x448 1 Face, 62.8ms
# Speed: 1.0ms preprocess, 62.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body124.png: 640x480 1 Face, 75.3ms
# Speed: 1.4ms preprocess, 75.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body125.png: 416x640 1 Face, 77.7ms
# Speed: 1.3ms preprocess, 77.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body126.png: 640x544 1 Face, 83.2ms
# Speed: 1.1ms preprocess, 83.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body127.png: 640x480 1 Face, 65.5ms
# Speed: 1.2ms preprocess, 65.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body128.png: 640x640 1 Face, 90.0ms
# Speed: 1.5ms preprocess, 90.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body129.png: 640x608 1 Face, 103.8ms
# Speed: 1.7ms preprocess, 103.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body13.png: 640x480 1 Face, 67.2ms
# Speed: 1.1ms preprocess, 67.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body130.png: 640x576 1 Face, 96.9ms
# Speed: 2.1ms preprocess, 96.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body131.png: 640x576 1 Face, 86.8ms
# Speed: 1.3ms preprocess, 86.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body132.png: 640x576 1 Face, 78.3ms
# Speed: 1.8ms preprocess, 78.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body133.png: 640x352 1 Face, 76.2ms
# Speed: 1.1ms preprocess, 76.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body134.png: 640x640 1 Face, 86.8ms
# Speed: 1.5ms preprocess, 86.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body135.png: 416x640 1 Face, 68.1ms
# Speed: 1.6ms preprocess, 68.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body136.png: 512x640 2 Faces, 91.7ms
# Speed: 1.6ms preprocess, 91.7ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body137.png: 640x256 1 Face, 51.6ms
# Speed: 0.9ms preprocess, 51.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 256)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body138.png: 640x448 1 Face, 62.0ms
# Speed: 1.3ms preprocess, 62.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body139.png: 640x448 2 Faces, 62.1ms
# Speed: 1.1ms preprocess, 62.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body14.png: 640x512 (no detections), 71.6ms
# Speed: 1.2ms preprocess, 71.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body140.png: 640x288 1 Face, 57.0ms
# Speed: 0.9ms preprocess, 57.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body141.png: 640x640 1 Face, 89.5ms
# Speed: 1.8ms preprocess, 89.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body142.png: 640x288 2 Faces, 52.5ms
# Speed: 1.0ms preprocess, 52.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body143.png: 640x416 2 Faces, 76.0ms
# Speed: 1.4ms preprocess, 76.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body144.png: 640x512 1 Face, 89.1ms
# Speed: 1.5ms preprocess, 89.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body145.png: 640x544 1 Face, 80.8ms
# Speed: 1.6ms preprocess, 80.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body146.png: 448x640 1 Face, 85.1ms
# Speed: 1.2ms preprocess, 85.1ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body147.png: 480x640 1 Face, 86.6ms
# Speed: 1.3ms preprocess, 86.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body148.png: 416x640 1 Face, 57.5ms
# Speed: 1.1ms preprocess, 57.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body149.png: 480x640 1 Face, 70.4ms
# Speed: 1.3ms preprocess, 70.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body15.png: 640x512 1 Face, 70.2ms
# Speed: 1.1ms preprocess, 70.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body150.png: 640x384 1 Face, 73.1ms
# Speed: 1.1ms preprocess, 73.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body151.png: 640x576 1 Face, 108.7ms
# Speed: 1.4ms preprocess, 108.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body152.png: 640x544 2 Faces, 75.7ms
# Speed: 2.1ms preprocess, 75.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body153.png: 640x416 1 Face, 58.4ms
# Speed: 1.1ms preprocess, 58.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body154.png: 640x608 2 Faces, 105.2ms
# Speed: 1.5ms preprocess, 105.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body155.png: 640x576 1 Face, 78.0ms
# Speed: 1.8ms preprocess, 78.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body156.png: 640x544 2 Faces, 78.0ms
# Speed: 1.3ms preprocess, 78.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body157.png: 608x640 2 Faces, 113.1ms
# Speed: 1.5ms preprocess, 113.1ms inference, 0.8ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body158.png: 608x640 2 Faces, 88.3ms
# Speed: 1.7ms preprocess, 88.3ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body159.png: 640x576 2 Faces, 80.9ms
# Speed: 1.5ms preprocess, 80.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body16.png: 448x640 1 Face, 61.1ms
# Speed: 1.6ms preprocess, 61.1ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body160.png: 576x640 1 Face, 94.2ms
# Speed: 1.4ms preprocess, 94.2ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body161.png: 640x416 1 Face, 57.5ms
# Speed: 1.0ms preprocess, 57.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body162.png: 640x608 1 Face, 84.3ms
# Speed: 1.5ms preprocess, 84.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body163.png: 640x640 2 Faces, 103.8ms
# Speed: 1.6ms preprocess, 103.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body164.png: 640x640 1 Face, 87.6ms
# Speed: 1.6ms preprocess, 87.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body165.png: 640x608 2 Faces, 84.3ms
# Speed: 1.4ms preprocess, 84.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body166.png: 640x576 (no detections), 81.2ms
# Speed: 1.6ms preprocess, 81.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body167.png: 640x640 1 Face, 88.1ms
# Speed: 1.5ms preprocess, 88.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body168.png: 640x512 1 Face, 72.6ms
# Speed: 1.2ms preprocess, 72.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body169.png: 576x640 1 Face, 81.1ms
# Speed: 1.2ms preprocess, 81.1ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body17.png: 640x480 1 Face, 85.4ms
# Speed: 1.3ms preprocess, 85.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body170.png: 544x640 2 Faces, 95.2ms
# Speed: 1.3ms preprocess, 95.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body171.png: 640x576 1 Face, 80.5ms
# Speed: 1.5ms preprocess, 80.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body172.png: 640x320 1 Face, 71.5ms
# Speed: 1.1ms preprocess, 71.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body173.png: 640x448 1 Face, 82.1ms
# Speed: 1.6ms preprocess, 82.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body174.png: 608x640 1 Face, 86.0ms
# Speed: 1.3ms preprocess, 86.0ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body175.png: 640x544 1 Face, 107.8ms
# Speed: 1.4ms preprocess, 107.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body176.png: 640x416 1 Face, 57.8ms
# Speed: 0.8ms preprocess, 57.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body177.png: 576x640 1 Face, 83.2ms
# Speed: 1.3ms preprocess, 83.2ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body178.png: 640x608 (no detections), 84.9ms
# Speed: 1.2ms preprocess, 84.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body179.png: 640x544 1 Face, 77.3ms
# Speed: 1.4ms preprocess, 77.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body18.png: 640x512 1 Face, 70.5ms
# Speed: 1.6ms preprocess, 70.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body180.png: 576x640 1 Face, 87.9ms
# Speed: 1.2ms preprocess, 87.9ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body181.png: 640x544 (no detections), 77.0ms
# Speed: 1.2ms preprocess, 77.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body182.png: 640x544 1 Face, 74.8ms
# Speed: 1.4ms preprocess, 74.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body183.png: 512x640 1 Face, 89.8ms
# Speed: 1.5ms preprocess, 89.8ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body184.png: 640x416 (no detections), 58.9ms
# Speed: 1.0ms preprocess, 58.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body185.png: 544x640 1 Face, 78.2ms
# Speed: 1.3ms preprocess, 78.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body186.png: 640x352 2 Faces, 69.5ms
# Speed: 0.9ms preprocess, 69.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body187.png: 640x384 1 Face, 74.5ms
# Speed: 1.0ms preprocess, 74.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body188.png: 576x640 1 Face, 80.9ms
# Speed: 1.7ms preprocess, 80.9ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body189.png: 640x352 1 Face, 52.8ms
# Speed: 0.8ms preprocess, 52.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body19.png: 640x640 1 Face, 138.1ms
# Speed: 1.9ms preprocess, 138.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body190.png: 640x640 3 Faces, 99.1ms
# Speed: 1.4ms preprocess, 99.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body191.png: 640x544 1 Face, 77.5ms
# Speed: 1.1ms preprocess, 77.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body192.png: 640x352 (no detections), 59.7ms
# Speed: 1.0ms preprocess, 59.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body193.png: 640x352 1 Face, 51.7ms
# Speed: 0.8ms preprocess, 51.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body194.png: 640x544 3 Faces, 80.8ms
# Speed: 1.3ms preprocess, 80.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body195.png: 640x512 1 Face, 77.6ms
# Speed: 1.3ms preprocess, 77.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body196.png: 640x512 1 Face, 77.1ms
# Speed: 1.1ms preprocess, 77.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body197.png: 480x640 1 Face, 89.2ms
# Speed: 1.1ms preprocess, 89.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body198.png: 640x416 1 Face, 78.3ms
# Speed: 1.1ms preprocess, 78.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body199.png: 640x288 1 Face, 58.6ms
# Speed: 0.8ms preprocess, 58.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body2.png: 640x480 1 Face, 82.6ms
# Speed: 1.4ms preprocess, 82.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body20.png: 640x640 1 Face, 105.3ms
# Speed: 1.9ms preprocess, 105.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body200.png: 640x576 1 Face, 101.2ms
# Speed: 1.8ms preprocess, 101.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body201.png: 640x320 1 Face, 61.3ms
# Speed: 0.8ms preprocess, 61.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body202.png: 640x480 1 Face, 69.1ms
# Speed: 1.5ms preprocess, 69.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body203.png: 640x480 1 Face, 83.4ms
# Speed: 1.6ms preprocess, 83.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body204.png: 640x640 2 Faces, 110.3ms
# Speed: 2.0ms preprocess, 110.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body205.png: 640x640 1 Face, 96.5ms
# Speed: 1.7ms preprocess, 96.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body206.png: 640x576 1 Face, 85.3ms
# Speed: 1.3ms preprocess, 85.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body207.png: 640x448 1 Face, 79.9ms
# Speed: 1.0ms preprocess, 79.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body208.png: 480x640 (no detections), 80.3ms
# Speed: 1.4ms preprocess, 80.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body209.png: 576x640 (no detections), 81.3ms
# Speed: 1.6ms preprocess, 81.3ms inference, 0.4ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body21.png: 640x448 1 Face, 63.4ms
# Speed: 1.4ms preprocess, 63.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body210.png: 640x512 1 Face, 74.0ms
# Speed: 1.2ms preprocess, 74.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body211.png: 544x640 1 Face, 94.4ms
# Speed: 1.4ms preprocess, 94.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body212.png: 640x544 1 Face, 102.3ms
# Speed: 1.7ms preprocess, 102.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body213.png: 640x640 1 Face, 88.3ms
# Speed: 1.6ms preprocess, 88.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body214.png: 640x512 1 Face, 73.3ms
# Speed: 1.2ms preprocess, 73.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body215.png: 640x576 3 Faces, 79.3ms
# Speed: 1.5ms preprocess, 79.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body216.png: 544x640 1 Face, 80.3ms
# Speed: 1.8ms preprocess, 80.3ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body217.png: 544x640 2 Faces, 79.0ms
# Speed: 1.2ms preprocess, 79.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body218.png: 384x640 1 Face, 79.8ms
# Speed: 1.3ms preprocess, 79.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body219.png: 640x608 1 Face, 103.5ms
# Speed: 1.5ms preprocess, 103.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body22.png: 640x448 1 Face, 62.0ms
# Speed: 1.3ms preprocess, 62.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body220.png: 544x640 1 Face, 100.1ms
# Speed: 1.3ms preprocess, 100.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body221.png: 640x384 1 Face, 70.4ms
# Speed: 1.5ms preprocess, 70.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body222.png: 640x416 (no detections), 74.2ms
# Speed: 1.0ms preprocess, 74.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body223.png: 640x384 1 Face, 60.0ms
# Speed: 1.1ms preprocess, 60.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body224.png: 512x640 1 Face, 86.4ms
# Speed: 1.3ms preprocess, 86.4ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body225.png: 640x416 1 Face, 58.0ms
# Speed: 1.0ms preprocess, 58.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body226.png: 640x448 1 Face, 59.8ms
# Speed: 1.1ms preprocess, 59.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body227.png: 640x416 1 Face, 56.4ms
# Speed: 1.0ms preprocess, 56.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body228.png: 544x640 1 Face, 76.1ms
# Speed: 1.4ms preprocess, 76.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body229.png: 640x448 1 Face, 61.5ms
# Speed: 1.1ms preprocess, 61.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body23.png: 640x544 1 Face, 76.5ms
# Speed: 1.2ms preprocess, 76.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body230.png: 640x320 1 Face, 65.5ms
# Speed: 0.7ms preprocess, 65.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body231.png: 544x640 1 Face, 78.8ms
# Speed: 1.3ms preprocess, 78.8ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body232.png: 544x640 1 Face, 76.5ms
# Speed: 1.4ms preprocess, 76.5ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body233.png: 512x640 2 Faces, 71.5ms
# Speed: 1.6ms preprocess, 71.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body234.png: 640x384 1 Face, 60.6ms
# Speed: 0.9ms preprocess, 60.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body235.png: 640x256 1 Face, 53.6ms
# Speed: 0.7ms preprocess, 53.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 256)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body236.png: 576x640 3 Faces, 95.9ms
# Speed: 1.3ms preprocess, 95.9ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body237.png: 416x640 1 Face, 71.5ms
# Speed: 0.9ms preprocess, 71.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body238.png: 640x352 (no detections), 74.3ms
# Speed: 0.9ms preprocess, 74.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body239.png: 512x640 1 Face, 68.3ms
# Speed: 1.1ms preprocess, 68.3ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body24.png: 640x576 1 Face, 94.8ms
# Speed: 1.1ms preprocess, 94.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body240.png: 416x640 1 Face, 56.0ms
# Speed: 1.2ms preprocess, 56.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body241.png: 448x640 1 Face, 77.1ms
# Speed: 1.2ms preprocess, 77.1ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body242.png: 640x608 2 Faces, 99.0ms
# Speed: 1.6ms preprocess, 99.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body243.png: 640x224 1 Face, 62.1ms
# Speed: 0.8ms preprocess, 62.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 224)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body244.png: 640x384 1 Face, 66.9ms
# Speed: 1.5ms preprocess, 66.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body245.png: 480x640 1 Face, 91.5ms
# Speed: 1.4ms preprocess, 91.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body246.png: 416x640 2 Faces, 59.9ms
# Speed: 1.0ms preprocess, 59.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body247.png: 640x640 1 Face, 104.6ms
# Speed: 1.3ms preprocess, 104.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body248.png: 640x384 1 Face, 55.8ms
# Speed: 0.9ms preprocess, 55.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body249.png: 640x224 1 Face, 38.5ms
# Speed: 0.5ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 224)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body25.png: 640x480 (no detections), 82.7ms
# Speed: 1.1ms preprocess, 82.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body250.png: 640x288 1 Face, 55.5ms
# Speed: 0.8ms preprocess, 55.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body251.png: 640x576 1 Face, 84.1ms
# Speed: 1.1ms preprocess, 84.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body252.png: 640x288 1 Face, 44.5ms
# Speed: 0.8ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body253.png: 640x512 1 Face, 90.0ms
# Speed: 1.1ms preprocess, 90.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body254.png: 640x448 1 Face, 78.6ms
# Speed: 1.3ms preprocess, 78.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body255.png: 480x640 1 Face, 68.9ms
# Speed: 1.3ms preprocess, 68.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body256.png: 640x576 1 Face, 81.5ms
# Speed: 1.3ms preprocess, 81.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body257.png: 640x544 1 Face, 95.9ms
# Speed: 1.8ms preprocess, 95.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body258.png: 640x608 1 Face, 87.0ms
# Speed: 1.7ms preprocess, 87.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body259.png: 640x352 1 Face, 65.0ms
# Speed: 0.9ms preprocess, 65.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body26.png: 576x640 1 Face, 98.0ms
# Speed: 1.7ms preprocess, 98.0ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body260.png: 640x288 1 Face, 42.9ms
# Speed: 1.0ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body261.png: 640x320 1 Face, 62.3ms
# Speed: 0.9ms preprocess, 62.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body262.png: 640x288 1 Face, 45.7ms
# Speed: 0.9ms preprocess, 45.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body263.png: 448x640 1 Face, 79.5ms
# Speed: 1.0ms preprocess, 79.5ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body264.png: 544x640 1 Face, 95.7ms
# Speed: 1.4ms preprocess, 95.7ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body265.png: 640x640 1 Face, 111.0ms
# Speed: 1.7ms preprocess, 111.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body266.png: 608x640 1 Face, 100.6ms
# Speed: 1.5ms preprocess, 100.6ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body267.png: 640x352 1 Face, 51.3ms
# Speed: 0.8ms preprocess, 51.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body268.png: 640x480 2 Faces, 79.5ms
# Speed: 1.0ms preprocess, 79.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body269.png: 320x640 1 Face, 63.1ms
# Speed: 0.7ms preprocess, 63.1ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body27.png: 640x384 1 Face, 78.7ms
# Speed: 1.2ms preprocess, 78.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body270.png: 640x320 2 Faces, 49.0ms
# Speed: 0.7ms preprocess, 49.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body271.png: 576x640 1 Face, 83.2ms
# Speed: 1.3ms preprocess, 83.2ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
#
# ...
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body36.png: 352x640 1 Face, 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body37.png: 640x448 2 Faces, 75.1ms
# Speed: 1.0ms preprocess, 75.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body38.png: 640x576 2 Faces, 77.1ms
# Speed: 1.5ms preprocess, 77.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body39.png: 640x608 1 Face, 99.9ms
# Speed: 1.7ms preprocess, 99.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body4.png: 448x640 1 Face, 81.4ms
# Speed: 1.3ms preprocess, 81.4ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body40.png: 640x448 1 Face, 63.2ms
# Speed: 1.2ms preprocess, 63.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body41.png: 640x608 1 Face, 84.3ms
# Speed: 1.5ms preprocess, 84.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body42.png: 640x448 2 Faces, 60.2ms
# Speed: 1.1ms preprocess, 60.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body43.png: 640x384 1 Face, 70.7ms
# Speed: 1.2ms preprocess, 70.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body44.png: 640x416 2 Faces, 54.4ms
# Speed: 1.6ms preprocess, 54.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body45.png: 320x640 1 Face, 65.0ms
# Speed: 0.8ms preprocess, 65.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body46.png: 640x448 (no detections), 61.7ms
# Speed: 1.0ms preprocess, 61.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body47.png: 576x640 1 Face, 96.4ms
# Speed: 1.3ms preprocess, 96.4ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body48.png: 640x544 1 Face, 75.5ms
# Speed: 1.1ms preprocess, 75.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body49.png: 640x640 1 Face, 102.3ms
# Speed: 1.3ms preprocess, 102.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body5.png: 640x640 1 Face, 86.3ms
# Speed: 1.4ms preprocess, 86.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body50.png: 384x640 (no detections), 68.1ms
# Speed: 1.1ms preprocess, 68.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body51.png: 640x576 1 Face, 78.4ms
# Speed: 1.6ms preprocess, 78.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body52.png: 544x640 (no detections), 92.0ms
# Speed: 1.4ms preprocess, 92.0ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body53.png: 512x640 (no detections), 88.3ms
# Speed: 1.1ms preprocess, 88.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body54.png: 640x352 1 Face, 63.8ms
# Speed: 0.7ms preprocess, 63.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body55.png: 576x640 (no detections), 79.5ms
# Speed: 1.4ms preprocess, 79.5ms inference, 0.4ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body56.png: 640x480 2 Faces, 80.9ms
# Speed: 1.2ms preprocess, 80.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body57.png: 640x640 (no detections), 87.3ms
# Speed: 1.7ms preprocess, 87.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body58.png: 608x640 (no detections), 100.5ms
# Speed: 1.3ms preprocess, 100.5ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body59.png: 544x640 1 Face, 80.4ms
# Speed: 1.2ms preprocess, 80.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body6.png: 480x640 2 Faces, 82.6ms
# Speed: 1.9ms preprocess, 82.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body60.png: 640x384 2 Faces, 74.7ms
# Speed: 1.0ms preprocess, 74.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body61.png: 640x640 1 Face, 92.7ms
# Speed: 1.5ms preprocess, 92.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body62.png: 544x640 (no detections), 80.0ms
# Speed: 1.4ms preprocess, 80.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body63.png: 480x640 1 Face, 66.5ms
# Speed: 1.2ms preprocess, 66.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body64.png: 480x640 1 Face, 67.0ms
# Speed: 1.6ms preprocess, 67.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body65.png: 640x448 (no detections), 62.5ms
# Speed: 1.2ms preprocess, 62.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body66.png: 640x576 (no detections), 79.8ms
# Speed: 1.4ms preprocess, 79.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body67.png: 640x512 1 Face, 85.3ms
# Speed: 1.0ms preprocess, 85.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body68.png: 640x640 1 Face, 89.3ms
# Speed: 1.4ms preprocess, 89.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body69.png: 640x512 1 Face, 69.0ms
# Speed: 1.3ms preprocess, 69.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body7.png: 512x640 2 Faces, 66.9ms
# Speed: 1.8ms preprocess, 66.9ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body70.png: 288x640 (no detections), 65.7ms
# Speed: 1.1ms preprocess, 65.7ms inference, 0.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body71.png: 448x640 1 Face, 99.8ms
# Speed: 1.3ms preprocess, 99.8ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body72.png: 640x480 1 Face, 65.4ms
# Speed: 1.0ms preprocess, 65.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body73.png: 608x640 1 Face, 84.4ms
# Speed: 1.3ms preprocess, 84.4ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body74.png: 640x384 1 Face, 53.7ms
# Speed: 0.9ms preprocess, 53.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body75.png: 640x384 (no detections), 54.9ms
# Speed: 1.2ms preprocess, 54.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body76.png: 640x448 1 Face, 60.7ms
# Speed: 1.0ms preprocess, 60.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body77.png: 640x576 1 Face, 79.2ms
# Speed: 1.3ms preprocess, 79.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body78.png: 544x640 1 Face, 76.9ms
# Speed: 1.2ms preprocess, 76.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body79.png: 576x640 1 Face, 80.0ms
# Speed: 2.2ms preprocess, 80.0ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body8.png: 640x480 1 Face, 63.7ms
# Speed: 1.1ms preprocess, 63.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body80.png: 640x640 (no detections), 85.2ms
# Speed: 1.7ms preprocess, 85.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body81.png: 640x416 1 Face, 81.9ms
# Speed: 0.9ms preprocess, 81.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body82.png: 640x480 1 Face, 72.3ms
# Speed: 1.3ms preprocess, 72.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body83.png: 640x384 2 Faces, 62.5ms
# Speed: 0.8ms preprocess, 62.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body84.png: 640x416 (no detections), 62.2ms
# Speed: 1.1ms preprocess, 62.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body85.png: 640x480 1 Face, 65.8ms
# Speed: 1.6ms preprocess, 65.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body86.png: 640x480 1 Face, 64.9ms
# Speed: 1.3ms preprocess, 64.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body87.png: 448x640 1 Face, 62.6ms
# Speed: 1.2ms preprocess, 62.6ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body88.png: 640x640 1 Face, 88.1ms
# Speed: 1.4ms preprocess, 88.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body89.png: 640x480 2 Faces, 64.5ms
# Speed: 1.0ms preprocess, 64.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body9.png: 480x640 1 Face, 80.0ms
# Speed: 1.6ms preprocess, 80.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body90.png: 640x512 2 Faces, 88.4ms
# Speed: 1.4ms preprocess, 88.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body91.png: 640x640 1 Face, 89.3ms
# Speed: 1.9ms preprocess, 89.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body92.png: 640x640 1 Face, 89.0ms
# Speed: 1.4ms preprocess, 89.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body93.png: 608x640 1 Face, 96.1ms
# Speed: 1.4ms preprocess, 96.1ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body94.png: 640x608 (no detections), 104.3ms
# Speed: 1.4ms preprocess, 104.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body95.png: 640x640 1 Face, 88.4ms
# Speed: 1.5ms preprocess, 88.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body96.png: 640x640 1 Face, 88.8ms
# Speed: 1.5ms preprocess, 88.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body97.png: 640x608 1 Face, 82.9ms
# Speed: 1.5ms preprocess, 82.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body98.png: 640x640 2 Faces, 95.2ms
# Speed: 1.5ms preprocess, 95.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body99.png: 576x640 2 Faces, 77.6ms
# Speed: 1.6ms preprocess, 77.6ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)

# %% [markdown]
# <h3>Computation of the model performance</h3>

# %%
results = extract_metrics(GT, predictions, t=t)

tp, fp, fn = results.values()

print(results)
print(f"precision={tp/(tp+fp)}")
print(f"recall={tp/(tp+fn)}")
# Out:
# {'true_positives': 272, 'false_positives': 53, 'false_negatives': 69}
# precision=0.8369230769230769
# recall=0.7976539589442815

# %% [markdown]
# <h2>Graphs</h2>

# %%
"""
Precision and recall as a function of the confidence threshold
"""
iterators = [i/20 for i in range(1, 20, 1)]

data = dict()
n_pred_list = []

for i in iterators:
    pred = predict(model_path, test_set, i)
    results = extract_metrics(GT, pred, t=t)
    tp, fp, fn = results.values()
    if (tp+fp) == 0: precision = 0
    else: precision=tp/(tp+fp)

    if (tp+fn) == 0: recall = 0
    else: recall=tp/(tp+fn)
    data[i] = (precision, recall)
    n_pred = 0
    for values in pred.values():
        n_pred += len(values)
    n_pred_list.append(n_pred)
# Out:
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body0.png: 416x640 1 Face, 74.6ms
# Speed: 1.2ms preprocess, 74.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body1.png: 576x640 1 Face, 76.7ms
# Speed: 1.5ms preprocess, 76.7ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body10.png: 640x640 2 Faces, 86.6ms
# Speed: 1.6ms preprocess, 86.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body100.png: 640x384 1 Face, 52.1ms
# Speed: 1.1ms preprocess, 52.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body101.png: 640x448 2 Faces, 75.6ms
# Speed: 1.2ms preprocess, 75.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body102.png: 544x640 1 Face, 72.4ms
# Speed: 1.3ms preprocess, 72.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body103.png: 640x384 1 Face, 52.3ms
# Speed: 1.1ms preprocess, 52.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body104.png: 544x640 2 Faces, 76.5ms
# Speed: 1.2ms preprocess, 76.5ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body105.png: 640x480 2 Faces, 66.0ms
# Speed: 1.2ms preprocess, 66.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body106.png: 640x352 1 Face, 72.0ms
# Speed: 1.1ms preprocess, 72.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body107.png: 640x288 1 Face, 61.2ms
# Speed: 0.8ms preprocess, 61.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body108.png: 608x640 2 Faces, 100.2ms
# Speed: 1.4ms preprocess, 100.2ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body109.png: 640x544 2 Faces, 93.5ms
# Speed: 1.3ms preprocess, 93.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body11.png: 640x544 1 Face, 75.2ms
# Speed: 1.4ms preprocess, 75.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body110.png: 640x640 3 Faces, 93.1ms
# Speed: 1.4ms preprocess, 93.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body111.png: 608x640 1 Face, 79.6ms
# Speed: 1.7ms preprocess, 79.6ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body112.png: 640x512 2 Faces, 84.1ms
# Speed: 1.7ms preprocess, 84.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body113.png: 640x256 1 Face, 50.8ms
# Speed: 1.1ms preprocess, 50.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 256)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body114.png: 608x640 1 Face, 80.3ms
# Speed: 1.5ms preprocess, 80.3ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body115.png: 640x480 1 Face, 64.7ms
# Speed: 1.3ms preprocess, 64.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body116.png: 640x288 1 Face, 41.3ms
# Speed: 1.1ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body117.png: 640x384 1 Face, 52.1ms
# Speed: 1.2ms preprocess, 52.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body118.png: 640x480 1 Face, 68.5ms
# Speed: 1.9ms preprocess, 68.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body119.png: 576x640 1 Face, 76.6ms
# Speed: 1.8ms preprocess, 76.6ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body12.png: 640x640 1 Face, 86.4ms
# Speed: 1.4ms preprocess, 86.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body120.png: 640x512 1 Face, 67.5ms
# Speed: 1.3ms preprocess, 67.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body121.png: 640x544 1 Face, 73.6ms
# Speed: 1.3ms preprocess, 73.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body122.png: 640x480 1 Face, 62.9ms
# Speed: 1.4ms preprocess, 62.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body123.png: 640x448 1 Face, 57.1ms
# Speed: 1.1ms preprocess, 57.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body124.png: 640x480 1 Face, 64.6ms
# Speed: 1.4ms preprocess, 64.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body125.png: 416x640 1 Face, 66.6ms
# Speed: 1.2ms preprocess, 66.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body126.png: 640x544 1 Face, 72.0ms
# Speed: 1.5ms preprocess, 72.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body127.png: 640x480 1 Face, 66.9ms
# Speed: 1.3ms preprocess, 66.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body128.png: 640x640 1 Face, 92.4ms
# Speed: 2.1ms preprocess, 92.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body129.png: 640x608 1 Face, 131.3ms
# Speed: 2.4ms preprocess, 131.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body13.png: 640x480 1 Face, 68.0ms
# Speed: 1.2ms preprocess, 68.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body130.png: 640x576 1 Face, 98.3ms
# Speed: 1.8ms preprocess, 98.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body131.png: 640x576 1 Face, 81.2ms
# Speed: 2.0ms preprocess, 81.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body132.png: 640x576 1 Face, 85.6ms
# Speed: 1.5ms preprocess, 85.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body133.png: 640x352 1 Face, 65.9ms
# Speed: 1.5ms preprocess, 65.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body134.png: 640x640 1 Face, 89.6ms
# Speed: 1.8ms preprocess, 89.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body135.png: 416x640 1 Face, 55.5ms
# Speed: 1.2ms preprocess, 55.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body136.png: 512x640 2 Faces, 95.3ms
# Speed: 1.6ms preprocess, 95.3ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body137.png: 640x256 1 Face, 52.0ms
# Speed: 0.8ms preprocess, 52.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 256)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body138.png: 640x448 1 Face, 59.1ms
# Speed: 1.5ms preprocess, 59.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body139.png: 640x448 2 Faces, 59.8ms
# Speed: 1.2ms preprocess, 59.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body14.png: 640x512 (no detections), 68.8ms
# Speed: 1.7ms preprocess, 68.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body140.png: 640x288 1 Face, 56.1ms
# Speed: 0.9ms preprocess, 56.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body141.png: 640x640 1 Face, 85.8ms
# Speed: 1.8ms preprocess, 85.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body142.png: 640x288 2 Faces, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body143.png: 640x416 2 Faces, 70.7ms
# Speed: 1.2ms preprocess, 70.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body144.png: 640x512 1 Face, 70.8ms
# Speed: 1.4ms preprocess, 70.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body145.png: 640x544 1 Face, 84.1ms
# Speed: 1.4ms preprocess, 84.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body146.png: 448x640 1 Face, 76.7ms
# Speed: 1.4ms preprocess, 76.7ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body147.png: 480x640 1 Face, 82.9ms
# Speed: 1.3ms preprocess, 82.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body148.png: 416x640 1 Face, 54.8ms
# Speed: 1.1ms preprocess, 54.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body149.png: 480x640 1 Face, 67.1ms
# Speed: 1.2ms preprocess, 67.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body15.png: 640x512 1 Face, 70.2ms
# Speed: 1.2ms preprocess, 70.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body150.png: 640x384 1 Face, 66.4ms
# Speed: 1.3ms preprocess, 66.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body151.png: 640x576 1 Face, 94.3ms
# Speed: 1.3ms preprocess, 94.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body152.png: 640x544 2 Faces, 72.7ms
# Speed: 1.5ms preprocess, 72.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body153.png: 640x416 1 Face, 55.6ms
# Speed: 1.1ms preprocess, 55.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body154.png: 640x608 2 Faces, 100.3ms
# Speed: 1.5ms preprocess, 100.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body155.png: 640x576 1 Face, 90.8ms
# Speed: 1.4ms preprocess, 90.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body156.png: 640x544 2 Faces, 83.3ms
# Speed: 1.3ms preprocess, 83.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body157.png: 608x640 2 Faces, 106.2ms
# Speed: 1.8ms preprocess, 106.2ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body158.png: 608x640 2 Faces, 83.1ms
# Speed: 2.0ms preprocess, 83.1ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body159.png: 640x576 2 Faces, 81.3ms
# Speed: 1.2ms preprocess, 81.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body16.png: 448x640 1 Face, 69.4ms
# Speed: 1.4ms preprocess, 69.4ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body160.png: 576x640 1 Face, 100.0ms
# Speed: 1.3ms preprocess, 100.0ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body161.png: 640x416 1 Face, 55.4ms
# Speed: 1.0ms preprocess, 55.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body162.png: 640x608 1 Face, 84.0ms
# Speed: 1.5ms preprocess, 84.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body163.png: 640x640 2 Faces, 103.1ms
# Speed: 1.7ms preprocess, 103.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body164.png: 640x640 1 Face, 88.7ms
# Speed: 1.6ms preprocess, 88.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body165.png: 640x608 2 Faces, 84.6ms
# Speed: 1.7ms preprocess, 84.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body166.png: 640x576 (no detections), 79.3ms
# Speed: 1.4ms preprocess, 79.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body167.png: 640x640 1 Face, 87.0ms
# Speed: 1.6ms preprocess, 87.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body168.png: 640x512 1 Face, 76.9ms
# Speed: 1.3ms preprocess, 76.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body169.png: 576x640 1 Face, 81.6ms
# Speed: 1.3ms preprocess, 81.6ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body17.png: 640x480 1 Face, 78.9ms
# Speed: 1.2ms preprocess, 78.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body170.png: 544x640 2 Faces, 101.3ms
# Speed: 1.1ms preprocess, 101.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body171.png: 640x576 1 Face, 89.4ms
# Speed: 1.6ms preprocess, 89.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body172.png: 640x320 1 Face, 65.1ms
# Speed: 1.3ms preprocess, 65.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body173.png: 640x448 1 Face, 83.9ms
# Speed: 1.5ms preprocess, 83.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body174.png: 608x640 1 Face, 89.4ms
# Speed: 1.4ms preprocess, 89.4ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body175.png: 640x544 1 Face, 94.7ms
# Speed: 1.5ms preprocess, 94.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body176.png: 640x416 1 Face, 59.4ms
# Speed: 1.4ms preprocess, 59.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body177.png: 576x640 1 Face, 80.2ms
# Speed: 1.1ms preprocess, 80.2ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body178.png: 640x608 (no detections), 84.5ms
# Speed: 1.3ms preprocess, 84.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body179.png: 640x544 1 Face, 79.6ms
# Speed: 1.4ms preprocess, 79.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body18.png: 640x512 1 Face, 73.3ms
# Speed: 1.5ms preprocess, 73.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body180.png: 576x640 1 Face, 87.2ms
# Speed: 1.6ms preprocess, 87.2ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body181.png: 640x544 (no detections), 80.7ms
# Speed: 1.4ms preprocess, 80.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body182.png: 640x544 1 Face, 79.1ms
# Speed: 1.4ms preprocess, 79.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body183.png: 512x640 1 Face, 92.8ms
# Speed: 1.5ms preprocess, 92.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body184.png: 640x416 (no detections), 58.8ms
# Speed: 1.2ms preprocess, 58.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body185.png: 544x640 1 Face, 83.1ms
# Speed: 1.5ms preprocess, 83.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body186.png: 640x352 2 Faces, 73.4ms
# Speed: 1.0ms preprocess, 73.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body187.png: 640x384 1 Face, 74.2ms
# Speed: 1.3ms preprocess, 74.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body188.png: 576x640 1 Face, 87.1ms
# Speed: 1.5ms preprocess, 87.1ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body189.png: 640x352 1 Face, 57.3ms
# Speed: 1.1ms preprocess, 57.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body19.png: 640x640 1 Face, 113.8ms
# Speed: 2.1ms preprocess, 113.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body190.png: 640x640 3 Faces, 140.5ms
# Speed: 2.0ms preprocess, 140.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body191.png: 640x544 1 Face, 80.7ms
# Speed: 1.5ms preprocess, 80.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body192.png: 640x352 (no detections), 53.2ms
# Speed: 1.2ms preprocess, 53.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body193.png: 640x352 1 Face, 50.2ms
# Speed: 0.9ms preprocess, 50.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body194.png: 640x544 3 Faces, 75.6ms
# Speed: 1.6ms preprocess, 75.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body195.png: 640x512 1 Face, 72.6ms
# Speed: 1.2ms preprocess, 72.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body196.png: 640x512 1 Face, 72.5ms
# Speed: 1.3ms preprocess, 72.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body197.png: 480x640 1 Face, 84.5ms
# Speed: 1.3ms preprocess, 84.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body198.png: 640x416 1 Face, 56.1ms
# Speed: 1.0ms preprocess, 56.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body199.png: 640x288 1 Face, 57.8ms
# Speed: 0.9ms preprocess, 57.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body2.png: 640x480 1 Face, 87.3ms
# Speed: 1.2ms preprocess, 87.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body20.png: 640x640 1 Face, 84.1ms
# Speed: 2.1ms preprocess, 84.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body200.png: 640x576 1 Face, 95.5ms
# Speed: 1.7ms preprocess, 95.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body201.png: 640x320 1 Face, 72.4ms
# Speed: 1.1ms preprocess, 72.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body202.png: 640x480 1 Face, 66.0ms
# Speed: 1.5ms preprocess, 66.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body203.png: 640x480 1 Face, 65.7ms
# Speed: 1.6ms preprocess, 65.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body204.png: 640x640 2 Faces, 107.6ms
# Speed: 2.2ms preprocess, 107.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body205.png: 640x640 1 Face, 82.4ms
# Speed: 1.6ms preprocess, 82.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body206.png: 640x576 1 Face, 75.8ms
# Speed: 1.4ms preprocess, 75.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body207.png: 640x448 1 Face, 76.9ms
# Speed: 1.1ms preprocess, 76.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body208.png: 480x640 (no detections), 66.2ms
# Speed: 1.1ms preprocess, 66.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body209.png: 576x640 (no detections), 78.7ms
# Speed: 1.6ms preprocess, 78.7ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body21.png: 640x448 1 Face, 63.7ms
# Speed: 1.6ms preprocess, 63.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body210.png: 640x512 1 Face, 74.0ms
# Speed: 1.1ms preprocess, 74.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body211.png: 544x640 1 Face, 93.6ms
# Speed: 1.6ms preprocess, 93.6ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body212.png: 640x544 1 Face, 73.2ms
# Speed: 1.7ms preprocess, 73.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body213.png: 640x640 1 Face, 87.7ms
# Speed: 1.7ms preprocess, 87.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body214.png: 640x512 1 Face, 67.8ms
# Speed: 1.4ms preprocess, 67.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body215.png: 640x576 3 Faces, 75.3ms
# Speed: 1.3ms preprocess, 75.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body216.png: 544x640 1 Face, 71.2ms
# Speed: 1.1ms preprocess, 71.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body217.png: 544x640 2 Faces, 75.7ms
# Speed: 1.5ms preprocess, 75.7ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body218.png: 384x640 1 Face, 76.1ms
# Speed: 0.9ms preprocess, 76.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body219.png: 640x608 1 Face, 100.4ms
# Speed: 2.0ms preprocess, 100.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body22.png: 640x448 1 Face, 57.9ms
# Speed: 1.3ms preprocess, 57.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body220.png: 544x640 1 Face, 75.4ms
# Speed: 1.3ms preprocess, 75.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body221.png: 640x384 1 Face, 69.5ms
# Speed: 1.2ms preprocess, 69.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body222.png: 640x416 (no detections), 85.5ms
# Speed: 1.4ms preprocess, 85.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body223.png: 640x384 1 Face, 57.2ms
# Speed: 1.6ms preprocess, 57.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body224.png: 512x640 1 Face, 86.0ms
# Speed: 1.5ms preprocess, 86.0ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body225.png: 640x416 1 Face, 56.0ms
# Speed: 1.6ms preprocess, 56.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body226.png: 640x448 1 Face, 60.6ms
# Speed: 1.1ms preprocess, 60.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body227.png: 640x416 1 Face, 56.8ms
# Speed: 1.1ms preprocess, 56.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body228.png: 544x640 1 Face, 70.6ms
# Speed: 1.4ms preprocess, 70.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body229.png: 640x448 1 Face, 62.8ms
# Speed: 1.5ms preprocess, 62.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body23.png: 640x544 1 Face, 74.8ms
# Speed: 1.1ms preprocess, 74.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body230.png: 640x320 1 Face, 65.4ms
# Speed: 1.0ms preprocess, 65.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body231.png: 544x640 1 Face, 76.2ms
# Speed: 1.7ms preprocess, 76.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body232.png: 544x640 1 Face, 74.5ms
# Speed: 1.5ms preprocess, 74.5ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body233.png: 512x640 2 Faces, 68.4ms
# Speed: 2.9ms preprocess, 68.4ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body234.png: 640x384 1 Face, 54.4ms
# Speed: 1.8ms preprocess, 54.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body235.png: 640x256 1 Face, 52.4ms
# Speed: 0.8ms preprocess, 52.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 256)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body236.png: 576x640 3 Faces, 94.2ms
# Speed: 1.4ms preprocess, 94.2ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body237.png: 416x640 1 Face, 77.0ms
# Speed: 1.5ms preprocess, 77.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body238.png: 640x352 (no detections), 68.8ms
# Speed: 0.8ms preprocess, 68.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body239.png: 512x640 1 Face, 71.7ms
# Speed: 1.8ms preprocess, 71.7ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body24.png: 640x576 1 Face, 99.0ms
# Speed: 1.2ms preprocess, 99.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body240.png: 416x640 1 Face, 62.6ms
# Speed: 1.4ms preprocess, 62.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body241.png: 448x640 1 Face, 85.1ms
# Speed: 1.7ms preprocess, 85.1ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body242.png: 640x608 2 Faces, 108.2ms
# Speed: 2.1ms preprocess, 108.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body243.png: 640x224 1 Face, 56.5ms
# Speed: 0.9ms preprocess, 56.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 224)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body244.png: 640x384 1 Face, 57.9ms
# Speed: 1.5ms preprocess, 57.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body245.png: 480x640 1 Face, 92.9ms
# Speed: 1.9ms preprocess, 92.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body246.png: 416x640 2 Faces, 62.4ms
# Speed: 1.2ms preprocess, 62.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body247.png: 640x640 1 Face, 108.6ms
# Speed: 1.9ms preprocess, 108.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body248.png: 640x384 1 Face, 64.5ms
# Speed: 1.1ms preprocess, 64.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body249.png: 640x224 1 Face, 52.4ms
# Speed: 1.2ms preprocess, 52.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 224)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body25.png: 640x480 (no detections), 88.5ms
# Speed: 1.5ms preprocess, 88.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body250.png: 640x288 1 Face, 74.2ms
# Speed: 1.5ms preprocess, 74.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body251.png: 640x576 1 Face, 106.5ms
# Speed: 1.9ms preprocess, 106.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body252.png: 640x288 1 Face, 57.6ms
# Speed: 0.8ms preprocess, 57.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body253.png: 640x512 1 Face, 98.4ms
# Speed: 1.5ms preprocess, 98.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body254.png: 640x448 1 Face, 75.1ms
# Speed: 1.2ms preprocess, 75.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body255.png: 480x640 1 Face, 81.9ms
# Speed: 1.7ms preprocess, 81.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body256.png: 640x576 1 Face, 76.0ms
# Speed: 1.4ms preprocess, 76.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body257.png: 640x544 1 Face, 95.4ms
# Speed: 1.3ms preprocess, 95.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body258.png: 640x608 1 Face, 78.1ms
# Speed: 1.9ms preprocess, 78.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body259.png: 640x352 1 Face, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body26.png: 576x640 1 Face, 97.4ms
# Speed: 1.7ms preprocess, 97.4ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body260.png: 640x288 1 Face, 47.1ms
# Speed: 0.8ms preprocess, 47.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body261.png: 640x320 1 Face, 62.2ms
# Speed: 1.2ms preprocess, 62.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body262.png: 640x288 1 Face, 44.0ms
# Speed: 0.9ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body263.png: 448x640 1 Face, 76.8ms
# Speed: 1.3ms preprocess, 76.8ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body264.png: 544x640 1 Face, 89.4ms
# Speed: 1.4ms preprocess, 89.4ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body265.png: 640x640 1 Face, 95.0ms
# Speed: 1.6ms preprocess, 95.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body266.png: 608x640 1 Face, 96.1ms
# Speed: 1.4ms preprocess, 96.1ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body267.png: 640x352 1 Face, 50.6ms
# Speed: 0.9ms preprocess, 50.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body268.png: 640x480 2 Faces, 79.0ms
# Speed: 1.3ms preprocess, 79.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body269.png: 320x640 1 Face, 61.4ms
# Speed: 0.8ms preprocess, 61.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body27.png: 640x384 1 Face, 65.8ms
# Speed: 1.4ms preprocess, 65.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body270.png: 640x320 2 Faces, 54.4ms
# Speed: 0.7ms preprocess, 54.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body271.png: 576x640 1 Face, 75.6ms
# Speed: 1.5ms preprocess, 75.6ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body272.png: 640x320 1 Face, 45.7ms
# Speed: 0.7ms preprocess, 45.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body273.png: 640x480 1 Face, 66.2ms
# Speed: 1.0ms preprocess, 66.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body274.png: 640x480 1 Face, 70.2ms
# Speed: 1.5ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body275.png: 640x224 (no detections), 53.1ms
# Speed: 0.7ms preprocess, 53.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 224)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body276.png: 640x384 1 Face, 59.7ms
# Speed: 1.0ms preprocess, 59.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body277.png: 576x640 1 Face, 78.4ms
# Speed: 1.6ms preprocess, 78.4ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body278.png: 640x576 1 Face, 99.1ms
# Speed: 1.6ms preprocess, 99.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body279.png: 608x640 1 Face, 80.7ms
# Speed: 1.6ms preprocess, 80.7ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body28.png: 640x544 1 Face, 103.4ms
# Speed: 1.7ms preprocess, 103.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body280.png: 640x256 1 Face, 70.4ms
# Speed: 1.3ms preprocess, 70.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 256)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body281.png: 640x384 1 Face, 55.3ms
# Speed: 1.1ms preprocess, 55.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body282.png: 640x512 1 Face, 90.8ms
# Speed: 1.5ms preprocess, 90.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body283.png: 640x256 1 Face, 41.3ms
# Speed: 0.8ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 256)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body284.png: 640x160 1 Face, 43.9ms
# Speed: 0.4ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 160)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body285.png: 640x512 1 Face, 78.0ms
# Speed: 1.7ms preprocess, 78.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body286.png: 640x512 (no detections), 67.3ms
# Speed: 1.4ms preprocess, 67.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body287.png: 640x608 1 Face, 105.2ms
# Speed: 1.7ms preprocess, 105.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body288.png: 640x544 1 Face, 81.2ms
# ...
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body36.png: 352x640 1 Face, 76.5ms
# Speed: 1.2ms preprocess, 76.5ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body37.png: 640x448 2 Faces, 117.3ms
# Speed: 1.4ms preprocess, 117.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body38.png: 640x576 2 Faces, 89.3ms
# Speed: 1.8ms preprocess, 89.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body39.png: 640x608 1 Face, 118.0ms
# Speed: 2.4ms preprocess, 118.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body4.png: 448x640 1 Face, 81.2ms
# Speed: 1.8ms preprocess, 81.2ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body40.png: 640x448 1 Face, 84.7ms
# Speed: 13.5ms preprocess, 84.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body41.png: 640x608 1 Face, 77.2ms
# Speed: 1.7ms preprocess, 77.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body42.png: 640x448 2 Faces, 67.0ms
# Speed: 1.3ms preprocess, 67.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body43.png: 640x384 1 Face, 76.0ms
# Speed: 1.5ms preprocess, 76.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body44.png: 640x416 2 Faces, 69.0ms
# Speed: 3.6ms preprocess, 69.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body45.png: 320x640 1 Face, 72.3ms
# Speed: 1.3ms preprocess, 72.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body46.png: 640x448 (no detections), 68.7ms
# Speed: 1.1ms preprocess, 68.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body47.png: 576x640 1 Face, 120.2ms
# Speed: 2.7ms preprocess, 120.2ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body48.png: 640x544 1 Face, 90.0ms
# Speed: 1.7ms preprocess, 90.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body49.png: 640x640 1 Face, 112.7ms
# Speed: 1.6ms preprocess, 112.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body5.png: 640x640 1 Face, 87.0ms
# Speed: 1.8ms preprocess, 87.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body50.png: 384x640 (no detections), 121.0ms
# Speed: 1.5ms preprocess, 121.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body51.png: 640x576 1 Face, 115.4ms
# Speed: 4.7ms preprocess, 115.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body52.png: 544x640 (no detections), 107.5ms
# Speed: 2.2ms preprocess, 107.5ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body53.png: 512x640 (no detections), 89.6ms
# Speed: 1.4ms preprocess, 89.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body54.png: 640x352 1 Face, 75.3ms
# Speed: 0.9ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body55.png: 576x640 (no detections), 81.7ms
# Speed: 2.2ms preprocess, 81.7ms inference, 0.4ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body56.png: 640x480 2 Faces, 106.2ms
# Speed: 1.8ms preprocess, 106.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body57.png: 640x640 (no detections), 82.1ms
# Speed: 1.5ms preprocess, 82.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body58.png: 608x640 (no detections), 98.9ms
# Speed: 1.6ms preprocess, 98.9ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body59.png: 544x640 1 Face, 76.8ms
# Speed: 1.5ms preprocess, 76.8ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body6.png: 480x640 2 Faces, 84.8ms
# Speed: 2.8ms preprocess, 84.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body60.png: 640x384 2 Faces, 71.6ms
# Speed: 1.0ms preprocess, 71.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body61.png: 640x640 1 Face, 85.7ms
# Speed: 2.0ms preprocess, 85.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body62.png: 544x640 (no detections), 79.7ms
# Speed: 1.7ms preprocess, 79.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body63.png: 480x640 1 Face, 71.6ms
# Speed: 1.3ms preprocess, 71.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body64.png: 480x640 1 Face, 78.5ms
# Speed: 1.7ms preprocess, 78.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body65.png: 640x448 (no detections), 68.5ms
# Speed: 1.3ms preprocess, 68.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body66.png: 640x576 (no detections), 77.7ms
# Speed: 1.7ms preprocess, 77.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body67.png: 640x512 1 Face, 86.9ms
# Speed: 1.4ms preprocess, 86.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body68.png: 640x640 1 Face, 86.3ms
# Speed: 1.7ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body69.png: 640x512 1 Face, 73.9ms
# Speed: 2.7ms preprocess, 73.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body7.png: 512x640 2 Faces, 74.6ms
# Speed: 2.6ms preprocess, 74.6ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body70.png: 288x640 (no detections), 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 0.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body71.png: 448x640 1 Face, 79.1ms
# Speed: 1.4ms preprocess, 79.1ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body72.png: 640x480 1 Face, 98.8ms
# Speed: 1.3ms preprocess, 98.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body73.png: 608x640 1 Face, 80.9ms
# Speed: 1.7ms preprocess, 80.9ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body74.png: 640x384 1 Face, 53.6ms
# Speed: 1.3ms preprocess, 53.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body75.png: 640x384 (no detections), 54.5ms
# Speed: 1.2ms preprocess, 54.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body76.png: 640x448 1 Face, 67.3ms
# Speed: 1.3ms preprocess, 67.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body77.png: 640x576 1 Face, 86.7ms
# Speed: 2.1ms preprocess, 86.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body78.png: 544x640 1 Face, 72.9ms
# Speed: 1.6ms preprocess, 72.9ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body79.png: 576x640 1 Face, 92.9ms
# Speed: 2.5ms preprocess, 92.9ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body8.png: 640x480 1 Face, 74.8ms
# Speed: 1.5ms preprocess, 74.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body80.png: 640x640 (no detections), 84.0ms
# Speed: 2.2ms preprocess, 84.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body81.png: 640x416 1 Face, 102.3ms
# Speed: 1.6ms preprocess, 102.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body82.png: 640x480 1 Face, 66.6ms
# Speed: 1.5ms preprocess, 66.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body83.png: 640x384 2 Faces, 55.9ms
# Speed: 1.1ms preprocess, 55.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body84.png: 640x416 (no detections), 62.4ms
# Speed: 1.3ms preprocess, 62.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body85.png: 640x480 1 Face, 67.2ms
# Speed: 2.7ms preprocess, 67.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body86.png: 640x480 1 Face, 65.6ms
# Speed: 1.5ms preprocess, 65.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body87.png: 448x640 1 Face, 60.3ms
# Speed: 1.4ms preprocess, 60.3ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body88.png: 640x640 1 Face, 93.4ms
# Speed: 1.8ms preprocess, 93.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body89.png: 640x480 2 Faces, 64.6ms
# Speed: 1.5ms preprocess, 64.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body9.png: 480x640 1 Face, 81.5ms
# Speed: 2.0ms preprocess, 81.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body90.png: 640x512 2 Faces, 111.5ms
# Speed: 1.4ms preprocess, 111.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body91.png: 640x640 1 Face, 82.2ms
# Speed: 1.7ms preprocess, 82.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body92.png: 640x640 1 Face, 86.6ms
# Speed: 1.8ms preprocess, 86.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body93.png: 608x640 1 Face, 78.1ms
# Speed: 2.1ms preprocess, 78.1ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body94.png: 640x608 (no detections), 111.3ms
# Speed: 1.8ms preprocess, 111.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body95.png: 640x640 1 Face, 84.3ms
# Speed: 1.7ms preprocess, 84.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body96.png: 640x640 1 Face, 89.1ms
# Speed: 1.7ms preprocess, 89.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body97.png: 640x608 1 Face, 79.5ms
# Speed: 1.8ms preprocess, 79.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body98.png: 640x640 2 Faces, 96.0ms
# Speed: 2.2ms preprocess, 96.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /home/theo/Documents/Unif/Master/Chimprec - Extra/Face Detection - test set/images/body99.png: 576x640 2 Faces, 112.9ms
# Speed: 2.3ms preprocess, 112.9ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)

# %%
# Sort data by t values
sorted_data = sorted(data.items())  
t_values, pr_recall = zip(*sorted_data)

# Extract precision and recall
precision_values, recall_values = zip(*pr_recall)

# Create the plot
plt.figure(figsize=(10, 5))
plt.plot(t_values, precision_values, label="Precision", color="deeppink", marker='o', linestyle='-')
plt.plot(t_values, recall_values, label="Recall", color="rebeccapurple", marker='s', linestyle='-')

# Labels and title
plt.xlabel("Confidence threshold")
plt.ylabel("Value")
plt.title(f"Precision and Recall as a function of the confidence threshold (iou_t = {t})")
plt.legend()
plt.grid(True)

# Set x-axis ticks to show all t values
plt.xticks(t_values, labels=[str(t) for t in t_values])  # Ensuring each t is explicitly labeled

# Display the plot
plt.savefig("plots/PR_according_to_CT.svg", format="svg")
plt.show()

n_gt = 0
for values in GT.values():
    n_gt += len(values)

# Create the plot
plt.figure(figsize=(10, 5))
plt.plot(t_values, [i/n_gt for i in n_pred_list], label="ratio n_pred/n_gt", color="blue", marker='o', linestyle='-')
plt.axhline(y=1, color='red', linestyle='--', linewidth=2, label="y = 1")

# Labels and title
plt.xlabel("Confidence threshold")
plt.ylabel("#pred / #ground truth")
plt.title(f"Number of predicted bboxes over number of ground truth bboxes as a function of the confidence threshold")
plt.grid(True)

# Set x-axis ticks to show all t values
plt.xticks(t_values, labels=[str(t) for t in t_values])  # Ensuring each t is explicitly labeled

# Display the plot
plt.savefig("plots/n_pred_over_n_gt.svg", format="svg")
plt.show()

# %%
best_matches = []
# Iterate over all unique image names in ground truths and predictions
for image_name in set(GT.keys()).union(predictions.keys()):
    gt_bboxes = GT.get(image_name, [])  # Retrieve ground truth bboxes (default empty list if missing)
    pred_bboxes = predictions.get(image_name, [])  # Retrieve predicted bboxes (default empty list if missing)
    
    
    
    # Iterate over each predicted bounding box
    for pred in pred_bboxes:
        best_iou = 0  # Initialize the best IoU score for the current prediction
        
        # Compare prediction with each ground truth bbox
        for i, gt in enumerate(gt_bboxes):
            score = iou(pred, gt)  # Compute IoU
            if score > best_iou:  # Update best match if IoU is higher
                best_iou = score

        best_matches.append(best_iou)


plt.figure(figsize=(8, 5))
sns.kdeplot(best_matches, fill=True, color="blue", bw_adjust=0.5, label="Density Curve")

plt.axvline(x=t, color='red', linestyle='--', linewidth=2, label=f"Threshold ({t})")

# Labels and title
plt.xlabel("Best matches")
plt.ylabel("Density")
plt.title("Distribution of the best IOU matches between ground truth and predicted bounding boxes")
plt.xlim(0, 1)  # Ensuring the range stays between 0 and 1
plt.grid(True)

# Add legend
plt.legend(loc="upper left")

# Show the plot
plt.savefig("plots/best_matches_distribution.svg", format="svg")
plt.show()

# %%
draw_predictions(predictions, GT, test_set, "visualisation")
