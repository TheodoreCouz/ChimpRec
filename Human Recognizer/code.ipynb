# %% [markdown]
# <h1>Test Code</h1>

# %% [markdown]
# <h2>Import the libraries</h2>

# %%
# !pip install opencv-python imgbeddings psycopg2-binary
import shutil
import cv2
import numpy as np
from imgbeddings import imgbeddings
from PIL import Image
import os
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/theo/.local/lib/python3.12/site-packages (4.10.0.84)
# Requirement already satisfied: imgbeddings in /home/theo/.local/lib/python3.12/site-packages (0.1.0)
# Requirement already satisfied: psycopg2-binary in /home/theo/.local/lib/python3.12/site-packages (2.9.9)
# Requirement already satisfied: numpy>=1.21.2 in /home/theo/.local/lib/python3.12/site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: transformers>=4.17.0 in /home/theo/.local/lib/python3.12/site-packages (from imgbeddings) (4.45.1)
# Requirement already satisfied: onnxruntime>=1.10.0 in /home/theo/.local/lib/python3.12/site-packages (from imgbeddings) (1.19.2)
# Requirement already satisfied: Pillow in /usr/lib64/python3.12/site-packages (from imgbeddings) (10.3.0)
# Requirement already satisfied: tqdm in /home/theo/.local/lib/python3.12/site-packages (from imgbeddings) (4.66.5)
# Requirement already satisfied: scikit-learn in /home/theo/.local/lib/python3.12/site-packages (from imgbeddings) (1.4.1.post1)
# Requirement already satisfied: coloredlogs in /home/theo/.local/lib/python3.12/site-packages (from onnxruntime>=1.10.0->imgbeddings) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/theo/.local/lib/python3.12/site-packages (from onnxruntime>=1.10.0->imgbeddings) (24.3.25)
# Requirement already satisfied: packaging in /usr/lib/python3.12/site-packages (from onnxruntime>=1.10.0->imgbeddings) (23.1)
# Requirement already satisfied: protobuf in /home/theo/.local/lib/python3.12/site-packages (from onnxruntime>=1.10.0->imgbeddings) (4.25.3)
# Requirement already satisfied: sympy in /home/theo/.local/lib/python3.12/site-packages (from onnxruntime>=1.10.0->imgbeddings) (1.13.3)
# Requirement already satisfied: filelock in /home/theo/.local/lib/python3.12/site-packages (from transformers>=4.17.0->imgbeddings) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/theo/.local/lib/python3.12/site-packages (from transformers>=4.17.0->imgbeddings) (0.25.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib64/python3.12/site-packages (from transformers>=4.17.0->imgbeddings) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/lib64/python3.12/site-packages (from transformers>=4.17.0->imgbeddings) (2024.4.28)
# Requirement already satisfied: requests in /usr/lib/python3.12/site-packages (from transformers>=4.17.0->imgbeddings) (2.28.2)
# Requirement already satisfied: safetensors>=0.4.1 in /home/theo/.local/lib/python3.12/site-packages (from transformers>=4.17.0->imgbeddings) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /home/theo/.local/lib/python3.12/site-packages (from transformers>=4.17.0->imgbeddings) (0.20.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/theo/.local/lib/python3.12/site-packages (from scikit-learn->imgbeddings) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/theo/.local/lib/python3.12/site-packages (from scikit-learn->imgbeddings) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/theo/.local/lib/python3.12/site-packages (from scikit-learn->imgbeddings) (3.3.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/theo/.local/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers>=4.17.0->imgbeddings) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/theo/.local/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers>=4.17.0->imgbeddings) (4.11.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/theo/.local/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.10.0->imgbeddings) (10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/lib/python3.12/site-packages (from requests->transformers>=4.17.0->imgbeddings) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.12/site-packages (from requests->transformers>=4.17.0->imgbeddings) (3.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3.12/site-packages (from requests->transformers>=4.17.0->imgbeddings) (1.26.20)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/theo/.local/lib/python3.12/site-packages (from sympy->onnxruntime>=1.10.0->imgbeddings) (1.3.0)

# %%
face_type = "chimps"

# %% [markdown]
# <h2>Load the face detection algorithm</h2>

# %%
# change the path according to your file system
haar_cascade = cv2.CascadeClassifier("/home/theo/Documents/Unif/Master/ChimpRec/Human Recognizer/haarcascade_frontalface_default.xml")

# %% [markdown]
# <h2>Isolate the detected faces</h2>

# %%
src_img = cv2.imread(f"{face_type}/dataset/Pasted image 9.png", 0)
src_img_grey = cv2.cvtColor(src_img, cv2.COLOR_RGB2BGR)

faces = haar_cascade.detectMultiScale(
    src_img_grey,
    scaleFactor=1.05,
    minNeighbors=1,
    minSize=(250, 250) # to adjust (40, 40) (250, 250)
)

i = 0

cropped_faces = []

if os.path.exists("stored-faces"):
    shutil.rmtree("stored-faces")
os.makedirs("stored-faces/")

for x, y, w, h in faces:
    cropped = src_img[y: y+h, x : x+w]
    cropped_faces.append(cropped)
    target_file_name = "stored-faces/" + str(i) + ".jpg"
    cv2.imwrite(
        target_file_name,
        cropped
    )
    i+=1

# %% [markdown]
# <h2>Compute the embedding vectors of the isolated faces</h2>

# %%
face_folder = "stored-faces"
ibed = imgbeddings()
# Out:
# /home/theo/.local/lib/python3.12/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'cached_download' (from 'huggingface_hub.file_download') is deprecated and will be removed from version '0.26'. Use `hf_hub_download` instead.
#   warnings.warn(warning_message, FutureWarning)
# /home/theo/.local/lib/python3.12/site-packages/huggingface_hub/file_download.py:672: FutureWarning: 'cached_download' is the legacy way to download files from the HF hub, please consider upgrading to 'hf_hub_download'
#   warnings.warn(
# /home/theo/.local/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /home/theo/.local/lib/python3.12/site-packages/transformers/models/clip/processing_clip.py:149: FutureWarning: `feature_extractor` is deprecated and will be removed in v5. Use `image_processor` instead.
#   warnings.warn(

# %%
embeddings = []

for filename in os.listdir(face_folder):
    img = Image.open(f"{face_folder}/{filename}")
    embedding = ibed.to_embeddings(img)
    embeddings.append(embedding)

if (len(embeddings) > 0):
    embeddings = np.array(embeddings).reshape(len(embeddings), -1)

# %% [markdown]
# <h2>Compute the embeddings of the labelized person.</h2>

# %%
known_embeddings = {}

for filename in os.listdir(f"{face_type}/dataset"):
    name = filename.split(".")[0]
    img = Image.open(os.path.join(f"{face_type}/dataset", filename))
    embedding = ibed.to_embeddings(img)
    known_embeddings[name] = embedding

# %% [markdown]
# <h2>Compare the computed embeddings to the known embeddings</h2>

# %%
n_matched = 0

for index, embed in enumerate(embeddings):
    best_sim = (0, "nobody")
    for name, known_embed in known_embeddings.items():
        # Ensure known embedding is reshaped to 2D for comparison
        sim = cosine_similarity(embed.reshape(1, -1), known_embed.reshape(1, -1))[0][0]
        if sim > best_sim[0] and sim > 0.8:
            best_sim = (sim, name)

    if best_sim[0] > 0:
        cropped = cropped_faces[index]
        if len(cropped.shape) == 2:
            cropped = cv2.cvtColor(cropped, cv2.COLOR_GRAY2BGR)
        guessed = cv2.imread(f"{face_type}/dataset/{best_sim[1]}.png")
        guessed_resized = cv2.resize(guessed, (cropped.shape[1], cropped.shape[0]))
        side_by_side = np.concatenate((cropped, guessed_resized), axis=1)
        side_by_side_rgb = cv2.cvtColor(side_by_side, cv2.COLOR_BGR2RGB)
        plt.imshow(side_by_side_rgb)
        plt.title(f"Matched with {best_sim[1]} (Similarity: {best_sim[0]:.2f})")
        plt.axis('off')
        plt.show()
        n_matched += 1

if n_matched == 0: print("no match for this picture")
